# %%
import argparse
import os
import shutil
from pathlib import Path

from _func import * # just import all helper functions

# %%
OUTPUT_FONT_NAME = "CodeCJK"
OUTPUT_FONT_VERSION = "005"
OUTPUT_FONT_FULL_NAME = f"{OUTPUT_FONT_NAME}{OUTPUT_FONT_VERSION}"

SRC_FONT_LIST = [
    {
        "id": "base",
        "type": "download_zip",
        "zip_url": "https://github.com/tonsky/FiraCode/releases/download/6.2/Fira_Code_v6.2.zip",
        "ttf_path_in_zip": "ttf/FiraCode-Regular.ttf",
        "ttf_filename": "FiraCode-Regular.ttf",
        "ttf_md5": "a09618fdaaa2aef4b7b45e26b7267763",
    },
    {
        "id": "patch0",
        "type": "ttf",
        "ttf_url": "https://github.com/googlefonts/Inconsolata/raw/refs/heads/main/fonts/ttf/Inconsolata-Regular.ttf",
        "ttf_filename": "Inconsolata-Regular.ttf",
        "ttf_md5": "6acebfd97d8edc5226a384f77c613398",
    },
    {
        "id": "cjk",
        "type": "ttf",
        "ttf_url": "https://github.com/notofonts/noto-cjk/raw/refs/heads/main/Sans/Variable/TTF/Mono/NotoSansMonoCJKhk-VF.ttf",
        "ttf_filename": "NotoSansMonoCJKhk-VF.ttf",
        "ttf_md5": "ffde7dc37f0754c486b1cc5486a7ae93",
    },
]

SRC_FONT_DICT = {font["id"]: font for font in SRC_FONT_LIST}

FONT_KEY_LIST = [font["id"] for font in SRC_FONT_LIST]

# %%
# check if running in a notebook

def is_notebook():
    try:
        shell = get_ipython().__class__.__name__
        if shell == 'ZMQInteractiveShell':
            return True   # Jupyter notebook or qtconsole
        elif shell == 'TerminalInteractiveShell':
            return False  # Terminal running IPython
        else:
            return False  # Other type (?)
    except NameError:
        return False      # Probably standard Python interpreter

IN_NOTEBOOK = is_notebook()

print(f"Running in notebook: {IN_NOTEBOOK}")
# Out:
# Running in notebook: True

# %%
if IN_NOTEBOOK:
    # get this ipynb script directory
    if 'original_cwd' not in globals():
        original_cwd = Path(os.getcwd())
        if os.path.exists(str(original_cwd / "build")):
            shutil.rmtree(str(original_cwd / "build"))
    # mkdir build
    os.makedirs(str(original_cwd / "build"), exist_ok=True)
    # change working directory to build
    os.chdir(str(original_cwd / "build"))

# %%
if not IN_NOTEBOOK:
    parser = argparse.ArgumentParser(description='Build CodeCJK font')
    parser.add_argument('--clean', action='store_true', help='Clean output and tmp folders before building')
    args = parser.parse_args()

    if args.clean:
        print("Cleaning output and tmp folders...")
        if os.path.exists("tmp"):
            shutil.rmtree("tmp")
        if os.path.exists("output"):
            shutil.rmtree("output")
        print("Cleaned.")

# %%
def ttf_milestone(next_milestone):
    last_milestone_str = f"{int(next_milestone)-1:02d}"
    next_milestone_str = f"{int(next_milestone):02d}"

    print(f"Z{next_milestone_str} milestone")
    for font_key in FONT_KEY_LIST:

        check_font(
            f"tmp/{font_key}.z{last_milestone_str}.99.ttf"
        )

        shutil.copyfile(
            f"tmp/{font_key}.z{last_milestone_str}.99.ttf",
            f"tmp/{font_key}.z{next_milestone_str}.00.ttf"
        )

        py(
            "ttf/dump_data_yaml.py",
            f"tmp/{font_key}.z{next_milestone_str}.00.ttf",
            f"tmp/{font_key}.z{next_milestone_str}.00.ttf.data.yaml",
        )
        py(
            "ttf/dump_char_csv.py",
            f"tmp/{font_key}.z{next_milestone_str}.00.ttf",
        )

# %%
# Get datetime string
YYYYMMDDHHMMSS = get_datetime_string()
print(f"Current datetime: {YYYYMMDDHHMMSS}")
# Out:
# Current datetime: 20260102222313

# %%
# Get script and project directories
script_dir = get_script_dir()
project_root = get_project_root()
print(f"Script directory: {script_dir}")
print(f"Project root directory: {project_root}")
# Out:
# Script directory: /home/luzi82/project/mono-merge/CodeCJK
# Project root directory: /home/luzi82/project/mono-merge

# %%
# Create folders
"""Create tmp and output folders in the working directory."""
os.makedirs("tmp", exist_ok=True)
os.makedirs("output", exist_ok=True)
print("Created tmp and output folders")
# Out:
# Created tmp and output folders

# %%
# Download and prepare fonts (includes MD5 verification)
download_fonts(SRC_FONT_LIST)
# Out:
# --- Processing font: base ---
# Downloading https://github.com/tonsky/FiraCode/releases/download/6.2/Fira_Code_v6.2.zip to tmp/Fira_Code_v6.2.zip
# Downloaded tmp/Fira_Code_v6.2.zip
# Extracting tmp/Fira_Code_v6.2.zip to tmp/Fira_Code_v6.2
# Extracted to tmp/Fira_Code_v6.2
# Verifying MD5 checksum for tmp/FiraCode-Regular.ttf
# MD5 checksum verified: OK
# Copying tmp/FiraCode-Regular.ttf to tmp/base.ttf
#
# --- Processing font: patch0 ---
# Found /home/luzi82/project/mono-merge/input/Inconsolata-Regular.ttf, copying to tmp/Inconsolata-Regular.ttf
# Verifying MD5 checksum for tmp/Inconsolata-Regular.ttf
# MD5 checksum verified: OK
# Copying tmp/Inconsolata-Regular.ttf to tmp/patch0.ttf
#
# --- Processing font: cjk ---
# Found /home/luzi82/project/mono-merge/input/NotoSansMonoCJKhk-VF.ttf, copying to tmp/NotoSansMonoCJKhk-VF.ttf
# Verifying MD5 checksum for tmp/NotoSansMonoCJKhk-VF.ttf
# MD5 checksum verified: OK
# Copying tmp/NotoSansMonoCJKhk-VF.ttf to tmp/cjk.ttf

# %%
# Set up Python environment
python_exe = setup_python_environment()
print(f"Using Python executable: {python_exe}")
# Out:
# Setting up Python environment...
# Requirement already satisfied: pip in ./tmp/venv/lib/python3.12/site-packages (24.0)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-25.3
# Collecting fonttools>=4.38.0 (from -r /home/luzi82/project/mono-merge/requirements.txt (line 1))
#   Using cached fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting Pillow>=9.0.0 (from -r /home/luzi82/project/mono-merge/requirements.txt (line 2))
#   Using cached pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting PyYAML>=6.0 (from -r /home/luzi82/project/mono-merge/requirements.txt (line 3))
#   Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting cu2qu>=1.6.7 (from -r /home/luzi82/project/mono-merge/requirements.txt (line 4))
#   Using cached cu2qu-1.6.7.post2-py2.py3-none-any.whl.metadata (1.3 kB)
# Using cached fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
# Using cached pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
# Using cached cu2qu-1.6.7.post2-py2.py3-none-any.whl (24 kB)
# Installing collected packages: PyYAML, Pillow, fonttools, cu2qu
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [cu2qu]32m3/4 [cu2qu]ols]
# Successfully installed Pillow-12.1.0 PyYAML-6.0.3 cu2qu-1.6.7.post2 fonttools-4.61.1
# Python environment setup complete
# Using Python executable: tmp/venv/bin/python

# %%
for font_key in FONT_KEY_LIST:
    shutil.copyfile(
        f"tmp/{font_key}.ttf",
        f"tmp/{font_key}.z00.99.ttf",
    )

ttf_milestone(1)
# Out:
# Z01 milestone
# Checking font: tmp/base.z00.99.ttf
# Font validation passed: tmp/base.z00.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/base.z01.00.ttf tmp/base.z01.00.ttf.data.yaml
# Font metadata written to tmp/base.z01.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/base.z01.00.ttf
# Successfully wrote 1586 codepoints to tmp/base.z01.00.ttf.codepoint.csv
# Successfully wrote 2030 glyphs to tmp/base.z01.00.ttf.glyph.csv
# Successfully wrote 1564 glyph references to tmp/base.z01.00.ttf.glyphref.csv
# Checking font: tmp/patch0.z00.99.ttf
# Font validation passed: tmp/patch0.z00.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/patch0.z01.00.ttf tmp/patch0.z01.00.ttf.data.yaml
# Font metadata written to tmp/patch0.z01.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/patch0.z01.00.ttf
# Successfully wrote 882 codepoints to tmp/patch0.z01.00.ttf.codepoint.csv
# Successfully wrote 964 glyphs to tmp/patch0.z01.00.ttf.glyph.csv
# Successfully wrote 921 glyph references to tmp/patch0.z01.00.ttf.glyphref.csv
# Checking font: tmp/cjk.z00.99.ttf
# Font validation passed: tmp/cjk.z00.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/cjk.z01.00.ttf tmp/cjk.z01.00.ttf.data.yaml
# Font metadata written to tmp/cjk.z01.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/cjk.z01.00.ttf
# Successfully wrote 44810 codepoints to tmp/cjk.z01.00.ttf.codepoint.csv
# Successfully wrote 65535 glyphs to tmp/cjk.z01.00.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/cjk.z01.00.ttf.glyphref.csv

# %%
print("Clear unused data from ttf files")
for font_key in FONT_KEY_LIST:

    linux_cmd(
        "ttfautohint",
        "--dehint",
        f"tmp/{font_key}.z01.00.ttf",
        f"tmp/{font_key}.z01.01.ttf",
    )

    py(
        "ttf/ttf_rm_table.py",
        f"tmp/{font_key}.z01.01.ttf",
        "GPOS,GSUB,vmtx,vhea,VORG,gasp",
        f"tmp/{font_key}.z01.02.ttf",
    )

    py(
        "ttf/ttf_post3.py",
        f"tmp/{font_key}.z01.02.ttf",
        f"tmp/{font_key}.z01.03.ttf"
    )

    shutil.copyfile(
        f"tmp/{font_key}.z01.03.ttf",
        f"tmp/{font_key}.z01.99.ttf",
    )
# Out:
# Clear unused data from ttf files
# Running command: ttfautohint --dehint tmp/base.z01.00.ttf tmp/base.z01.01.ttf
# Command succeeded: ttfautohint --dehint tmp/base.z01.00.ttf tmp/base.z01.01.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_rm_table.py tmp/base.z01.01.ttf GPOS,GSUB,vmtx,vhea,VORG,gasp tmp/base.z01.02.ttf
# Removed GPOS table
# Removed GSUB table
# vmtx table not found
# vhea table not found
# VORG table not found
# Removed gasp table
# Saved to tmp/base.z01.02.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_post3.py tmp/base.z01.02.ttf tmp/base.z01.03.ttf
# Converted post table to formatType 3: tmp/base.z01.03.ttf
# Running command: ttfautohint --dehint tmp/patch0.z01.00.ttf tmp/patch0.z01.01.ttf
# Command succeeded: ttfautohint --dehint tmp/patch0.z01.00.ttf tmp/patch0.z01.01.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_rm_table.py tmp/patch0.z01.01.ttf GPOS,GSUB,vmtx,vhea,VORG,gasp tmp/patch0.z01.02.ttf
# Removed GPOS table
# Removed GSUB table
# vmtx table not found
# vhea table not found
# VORG table not found
# Removed gasp table
# Saved to tmp/patch0.z01.02.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_post3.py tmp/patch0.z01.02.ttf tmp/patch0.z01.03.ttf
# Converted post table to formatType 3: tmp/patch0.z01.03.ttf
# Running command: ttfautohint --dehint tmp/cjk.z01.00.ttf tmp/cjk.z01.01.ttf
# Command succeeded: ttfautohint --dehint tmp/cjk.z01.00.ttf tmp/cjk.z01.01.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_rm_table.py tmp/cjk.z01.01.ttf GPOS,GSUB,vmtx,vhea,VORG,gasp tmp/cjk.z01.02.ttf
# Removed GPOS table
# Removed GSUB table
# Removed vmtx table
# Removed vhea table
# VORG table not found
# Removed gasp table
# Saved to tmp/cjk.z01.02.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_post3.py tmp/cjk.z01.02.ttf tmp/cjk.z01.03.ttf
# Converted post table to formatType 3: tmp/cjk.z01.03.ttf

# %%
ttf_milestone(2)
# Out:
# Z02 milestone
# Checking font: tmp/base.z01.99.ttf
# Font validation passed: tmp/base.z01.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/base.z02.00.ttf tmp/base.z02.00.ttf.data.yaml
# Font metadata written to tmp/base.z02.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/base.z02.00.ttf
# Successfully wrote 1586 codepoints to tmp/base.z02.00.ttf.codepoint.csv
# Successfully wrote 2030 glyphs to tmp/base.z02.00.ttf.glyph.csv
# Successfully wrote 1564 glyph references to tmp/base.z02.00.ttf.glyphref.csv
# Checking font: tmp/patch0.z01.99.ttf
# Font validation passed: tmp/patch0.z01.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/patch0.z02.00.ttf tmp/patch0.z02.00.ttf.data.yaml
# Font metadata written to tmp/patch0.z02.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/patch0.z02.00.ttf
# Successfully wrote 882 codepoints to tmp/patch0.z02.00.ttf.codepoint.csv
# Successfully wrote 964 glyphs to tmp/patch0.z02.00.ttf.glyph.csv
# Successfully wrote 921 glyph references to tmp/patch0.z02.00.ttf.glyphref.csv
# Checking font: tmp/cjk.z01.99.ttf
# Font validation passed: tmp/cjk.z01.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/cjk.z02.00.ttf tmp/cjk.z02.00.ttf.data.yaml
# Font metadata written to tmp/cjk.z02.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/cjk.z02.00.ttf
# Successfully wrote 44810 codepoints to tmp/cjk.z02.00.ttf.codepoint.csv
# Successfully wrote 65535 glyphs to tmp/cjk.z02.00.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/cjk.z02.00.ttf.glyphref.csv

# %%
# decompose composite glyphs
print("Decomposing composite glyphs...")
for font_key in FONT_KEY_LIST:
    py(
        "ttf/ttf_decompose_composite_glyph.py",
        f"tmp/{font_key}.z02.00.ttf",
        f"tmp/{font_key}.z02.01.ttf"
    )

    py(
        "ttf/dump_char_csv.py",
        f"tmp/{font_key}.z02.01.ttf",
    )

    py(
        "utils/csv_rm_column.py",
        f"tmp/{font_key}.z02.00.ttf.codepoint.csv",
        "glyph_index,glyph_name,cmap_used,num_contours",
        f"tmp/{font_key}.z02.02.ttf.codepoint.expected.0.csv",
    )
    py(
        "utils/csv_set_col.py",
        f"tmp/{font_key}.z02.02.ttf.codepoint.expected.0.csv",
        "is_composite:False,glyf_used:0,num_glyph:0",
        f"tmp/{font_key}.z02.02.ttf.codepoint.expected.9.csv",
    )
    py(
        "utils/csv_rm_column.py",
        f"tmp/{font_key}.z02.01.ttf.codepoint.csv",
        "glyph_index,glyph_name,cmap_used,num_contours",
        f"tmp/{font_key}.z02.02.ttf.codepoint.actual.csv",
    )
    py(
        "utils/diff.py",
        f"tmp/{font_key}.z02.02.ttf.codepoint.expected.9.csv",
        f"tmp/{font_key}.z02.02.ttf.codepoint.actual.csv",
    )

    num_contours_list = py(
        "utils/csv_dump_col.py",
        f"tmp/{font_key}.z02.01.ttf.codepoint.csv",
        "num_contours",
        stdout = False,
    ).split('\n')
    assert('-1' not in num_contours_list), "Error: still have composite glyphs!"

    is_composite_list = py(
        "utils/csv_dump_col.py",
        f"tmp/{font_key}.z02.01.ttf.glyph.csv",
        "is_composite",
        stdout = False,
    ).split('\n')
    assert('True' not in is_composite_list), "Error: still have composite glyphs!"

    shutil.copyfile(
        f"tmp/{font_key}.z02.01.ttf",
        f"tmp/{font_key}.z02.99.ttf",
    )
# Out:
# Decomposing composite glyphs...
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_decompose_composite_glyph.py tmp/base.z02.00.ttf tmp/base.z02.01.ttf
# Decomposed composite glyphs and saved to tmp/base.z02.01.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/base.z02.01.ttf
# Successfully wrote 1586 codepoints to tmp/base.z02.01.ttf.codepoint.csv
# Successfully wrote 2030 glyphs to tmp/base.z02.01.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/base.z02.01.ttf.glyphref.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/base.z02.00.ttf.codepoint.csv glyph_index,glyph_name,cmap_used,num_contours tmp/base.z02.02.ttf.codepoint.expected.0.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_set_col.py tmp/base.z02.02.ttf.codepoint.expected.0.csv is_composite:False,glyf_used:0,num_glyph:0 tmp/base.z02.02.ttf.codepoint.expected.9.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/base.z02.01.ttf.codepoint.csv glyph_index,glyph_name,cmap_used,num_contours tmp/base.z02.02.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/diff.py tmp/base.z02.02.ttf.codepoint.expected.9.csv tmp/base.z02.02.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_dump_col.py tmp/base.z02.01.ttf.codepoint.csv num_contours
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_dump_col.py tmp/base.z02.01.ttf.glyph.csv is_composite
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_decompose_composite_glyph.py tmp/patch0.z02.00.ttf tmp/patch0.z02.01.ttf
# Decomposed composite glyphs and saved to tmp/patch0.z02.01.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/patch0.z02.01.ttf
# Successfully wrote 882 codepoints to tmp/patch0.z02.01.ttf.codepoint.csv
# Successfully wrote 964 glyphs to tmp/patch0.z02.01.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/patch0.z02.01.ttf.glyphref.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/patch0.z02.00.ttf.codepoint.csv glyph_index,glyph_name,cmap_used,num_contours tmp/patch0.z02.02.ttf.codepoint.expected.0.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_set_col.py tmp/patch0.z02.02.ttf.codepoint.expected.0.csv is_composite:False,glyf_used:0,num_glyph:0 tmp/patch0.z02.02.ttf.codepoint.expected.9.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/patch0.z02.01.ttf.codepoint.csv glyph_index,glyph_name,cmap_used,num_contours tmp/patch0.z02.02.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/diff.py tmp/patch0.z02.02.ttf.codepoint.expected.9.csv tmp/patch0.z02.02.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_dump_col.py tmp/patch0.z02.01.ttf.codepoint.csv num_contours
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_dump_col.py tmp/patch0.z02.01.ttf.glyph.csv is_composite
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_decompose_composite_glyph.py tmp/cjk.z02.00.ttf tmp/cjk.z02.01.ttf
# Decomposed composite glyphs and saved to tmp/cjk.z02.01.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/cjk.z02.01.ttf
# Successfully wrote 44810 codepoints to tmp/cjk.z02.01.ttf.codepoint.csv
# Successfully wrote 65535 glyphs to tmp/cjk.z02.01.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/cjk.z02.01.ttf.glyphref.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/cjk.z02.00.ttf.codepoint.csv glyph_index,glyph_name,cmap_used,num_contours tmp/cjk.z02.02.ttf.codepoint.expected.0.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_set_col.py tmp/cjk.z02.02.ttf.codepoint.expected.0.csv is_composite:False,glyf_used:0,num_glyph:0 tmp/cjk.z02.02.ttf.codepoint.expected.9.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/cjk.z02.01.ttf.codepoint.csv glyph_index,glyph_name,cmap_used,num_contours tmp/cjk.z02.02.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/diff.py tmp/cjk.z02.02.ttf.codepoint.expected.9.csv tmp/cjk.z02.02.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_dump_col.py tmp/cjk.z02.01.ttf.codepoint.csv num_contours
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_dump_col.py tmp/cjk.z02.01.ttf.glyph.csv is_composite

# %%
ttf_milestone(3)
# Out:
# Z03 milestone
# Checking font: tmp/base.z02.99.ttf
# Font validation passed: tmp/base.z02.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/base.z03.00.ttf tmp/base.z03.00.ttf.data.yaml
# Font metadata written to tmp/base.z03.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/base.z03.00.ttf
# Successfully wrote 1586 codepoints to tmp/base.z03.00.ttf.codepoint.csv
# Successfully wrote 2030 glyphs to tmp/base.z03.00.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/base.z03.00.ttf.glyphref.csv
# Checking font: tmp/patch0.z02.99.ttf
# Font validation passed: tmp/patch0.z02.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/patch0.z03.00.ttf tmp/patch0.z03.00.ttf.data.yaml
# Font metadata written to tmp/patch0.z03.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/patch0.z03.00.ttf
# Successfully wrote 882 codepoints to tmp/patch0.z03.00.ttf.codepoint.csv
# Successfully wrote 964 glyphs to tmp/patch0.z03.00.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/patch0.z03.00.ttf.glyphref.csv
# Checking font: tmp/cjk.z02.99.ttf
# Font validation passed: tmp/cjk.z02.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/cjk.z03.00.ttf tmp/cjk.z03.00.ttf.data.yaml
# Font metadata written to tmp/cjk.z03.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/cjk.z03.00.ttf
# Successfully wrote 44810 codepoints to tmp/cjk.z03.00.ttf.codepoint.csv
# Successfully wrote 65535 glyphs to tmp/cjk.z03.00.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/cjk.z03.00.ttf.glyphref.csv

# %%
# rm unused glyphs
for font_key in FONT_KEY_LIST:

    py(
        "ttf/glyphcsv_used_mark_rm.py",
        f"tmp/{font_key}.z03.00.ttf.glyph.csv",
        f"tmp/{font_key}.z03.00.ttf.glyphref.csv",
        f"tmp/{font_key}.z03.01.rm_glyph.csv"
    )

    py(
        "ttf/ttf_rm_glyph.py",
        f"tmp/{font_key}.z03.00.ttf",
        f"tmp/{font_key}.z03.01.rm_glyph.csv",
        f"tmp/{font_key}.z03.02.ttf"
    )

    py(
        "ttf/dump_char_csv.py",
        f"tmp/{font_key}.z03.02.ttf",
    )

    py(
        "utils/csv_rm_column.py",
        f"tmp/{font_key}.z03.00.ttf.codepoint.csv",
        "glyph_index,glyph_name",
        f"tmp/{font_key}.z03.03.ttf.codepoint.expected.csv",
    )
    py(
        "utils/csv_rm_column.py",
        f"tmp/{font_key}.z03.02.ttf.codepoint.csv",
        "glyph_index,glyph_name",
        f"tmp/{font_key}.z03.03.ttf.codepoint.actual.csv",
    )
    py(
        "utils/diff.py",
        f"tmp/{font_key}.z03.03.ttf.codepoint.expected.csv",
        f"tmp/{font_key}.z03.03.ttf.codepoint.actual.csv",
    )

    shutil.copyfile(
        f"tmp/{font_key}.z03.02.ttf",
        f"tmp/{font_key}.z03.99.ttf",
    )
# Out:
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/glyphcsv_used_mark_rm.py tmp/base.z03.00.ttf.glyph.csv tmp/base.z03.00.ttf.glyphref.csv tmp/base.z03.01.rm_glyph.csv
# Successfully processed 2030 glyphs
# Glyphs marked for removal: 443
# Glyphs reachable from cmap: 1586
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_rm_glyph.py tmp/base.z03.00.ttf tmp/base.z03.01.rm_glyph.csv tmp/base.z03.02.ttf
# Reading CSV: tmp/base.z03.01.rm_glyph.csv
# Found 443 glyphs marked for removal
# Loading font: tmp/base.z03.00.ttf
# Removing glyph: glyph00129
# Removing glyph: glyph00130
# Removing glyph: glyph00131
# Removing glyph: glyph00132
# Removing glyph: glyph00133
# Removing glyph: glyph00134
# Removing glyph: glyph00135
# Removing glyph: glyph00136
# Removing glyph: glyph00137
# Removing glyph: glyph00186
# Removing glyph: glyph00270
# Removing glyph: glyph00271
# Removing glyph: glyph00272
# Removing glyph: glyph00273
# Removing glyph: glyph00274
# Removing glyph: glyph00275
# Removing glyph: glyph00276
# Removing glyph: glyph00277
# Removing glyph: glyph00278
# Removing glyph: glyph00279
# Removing glyph: glyph00280
# Removing glyph: glyph00281
# Removing glyph: glyph00282
# Removing glyph: glyph00283
# Removing glyph: glyph00284
# Removing glyph: glyph00285
# Removing glyph: glyph00286
# Removing glyph: glyph00287
# Removing glyph: glyph00288
# Removing glyph: glyph00289
# Removing glyph: glyph00290
# Removing glyph: glyph00291
# Removing glyph: glyph00292
# Removing glyph: glyph00293
# Removing glyph: glyph00294
# Removing glyph: glyph00295
# Removing glyph: glyph00296
# Removing glyph: glyph00297
# Removing glyph: glyph00298
# Removing glyph: glyph00299
# Removing glyph: glyph00300
# Removing glyph: glyph00301
# Removing glyph: glyph00302
# Removing glyph: glyph00303
# Removing glyph: glyph00304
# Removing glyph: glyph00305
# Removing glyph: glyph00306
# Removing glyph: glyph00307
# Removing glyph: glyph00308
# Removing glyph: glyph00309
# Removing glyph: glyph00310
# Removing glyph: glyph00311
# Removing glyph: glyph00312
# Removing glyph: glyph00313
# Removing glyph: glyph00314
# Removing glyph: glyph00315
# Removing glyph: glyph00316
# Removing glyph: glyph00317
# Removing glyph: glyph00318
# Removing glyph: glyph00319
# Removing glyph: glyph00320
# Removing glyph: glyph00321
# Removing glyph: glyph00322
# Removing glyph: glyph00323
# Removing glyph: glyph00324
# Removing glyph: glyph00325
# Removing glyph: glyph00326
# Removing glyph: glyph00327
# Removing glyph: glyph00328
# Removing glyph: glyph00329
# Removing glyph: glyph00330
# Removing glyph: glyph00331
# Removing glyph: glyph00332
# Removing glyph: glyph00333
# Removing glyph: glyph00334
# Removing glyph: glyph00335
# Removing glyph: glyph00336
# Removing glyph: glyph00337
# Removing glyph: glyph00338
# Removing glyph: glyph00339
# Removing glyph: glyph00340
# Removing glyph: glyph00341
# Removing glyph: glyph00342
# Removing glyph: glyph00343
# Removing glyph: glyph00344
# Removing glyph: glyph00345
# Removing glyph: glyph00346
# Removing glyph: glyph00347
# Removing glyph: glyph00348
# Removing glyph: glyph00349
# Removing glyph: glyph00350
# Removing glyph: glyph00351
# Removing glyph: glyph00352
# Removing glyph: glyph00353
# Removing glyph: glyph00354
# Removing glyph: glyph00355
# Removing glyph: glyph00356
# Removing glyph: glyph00357
# Removing glyph: glyph00358
# Removing glyph: glyph00359
# Removing glyph: glyph00360
# Removing glyph: glyph00361
# Removing glyph: glyph00362
# Removing glyph: glyph00363
# Removing glyph: glyph00364
# Removing glyph: glyph00365
# Removing glyph: glyph00366
# Removing glyph: glyph00367
# Removing glyph: glyph00368
# Removing glyph: glyph00369
# Removing glyph: glyph00370
# Removing glyph: glyph00371
# Removing glyph: glyph01015
# Removing glyph: glyph01016
# Removing glyph: glyph01017
# Removing glyph: glyph01018
# Removing glyph: glyph01019
# Removing glyph: glyph01020
# Removing glyph: glyph01021
# Removing glyph: glyph01022
# Removing glyph: glyph01023
# Removing glyph: glyph01024
# Removing glyph: glyph01025
# Removing glyph: glyph01026
# Removing glyph: glyph01027
# Removing glyph: glyph01028
# Removing glyph: glyph01029
# Removing glyph: glyph01030
# Removing glyph: glyph01031
# Removing glyph: glyph01032
# Removing glyph: glyph01033
# Removing glyph: glyph01034
# Removing glyph: glyph01035
# Removing glyph: glyph01036
# Removing glyph: glyph01037
# Removing glyph: glyph01038
# Removing glyph: glyph01039
# Removing glyph: glyph01040
# Removing glyph: glyph01041
# Removing glyph: glyph01042
# Removing glyph: glyph01043
# Removing glyph: glyph01044
# Removing glyph: glyph01045
# Removing glyph: glyph01046
# Removing glyph: glyph01047
# Removing glyph: glyph01058
# Removing glyph: glyph01059
# Removing glyph: glyph01060
# Removing glyph: glyph01061
# Removing glyph: glyph01062
# Removing glyph: glyph01063
# Removing glyph: glyph01064
# Removing glyph: glyph01065
# Removing glyph: glyph01066
# Removing glyph: glyph01067
# Removing glyph: glyph01095
# Removing glyph: glyph01096
# Removing glyph: glyph01097
# Removing glyph: glyph01098
# Removing glyph: glyph01106
# Removing glyph: glyph01107
# Removing glyph: glyph01112
# Removing glyph: glyph01113
# Removing glyph: glyph01114
# Removing glyph: glyph01115
# Removing glyph: glyph01116
# Removing glyph: glyph01118
# Removing glyph: glyph01119
# Removing glyph: glyph01120
# Removing glyph: glyph01121
# Removing glyph: glyph01122
# Removing glyph: glyph01125
# Removing glyph: glyph01126
# Removing glyph: glyph01127
# Removing glyph: glyph01128
# Removing glyph: glyph01130
# Removing glyph: glyph01133
# Removing glyph: glyph01134
# Removing glyph: glyph01135
# Removing glyph: glyph01136
# Removing glyph: glyph01139
# Removing glyph: glyph01140
# Removing glyph: glyph01141
# Removing glyph: glyph01146
# Removing glyph: glyph01147
# Removing glyph: glyph01148
# Removing glyph: glyph01149
# Removing glyph: glyph01152
# Removing glyph: glyph01153
# Removing glyph: glyph01154
# Removing glyph: glyph01155
# Removing glyph: glyph01156
# Removing glyph: glyph01157
# Removing glyph: glyph01158
# Removing glyph: glyph01159
# Removing glyph: glyph01160
# Removing glyph: glyph01161
# Removing glyph: glyph01163
# Removing glyph: glyph01164
# Removing glyph: glyph01165
# Removing glyph: glyph01166
# Removing glyph: glyph01167
# Removing glyph: glyph01169
# Removing glyph: glyph01171
# Removing glyph: glyph01172
# Removing glyph: glyph01173
# Removing glyph: glyph01174
# Removing glyph: glyph01175
# Removing glyph: glyph01176
# Removing glyph: glyph01177
# Removing glyph: glyph01178
# Removing glyph: glyph01179
# Removing glyph: glyph01180
# Removing glyph: glyph01181
# Removing glyph: glyph01182
# Removing glyph: glyph01183
# Removing glyph: glyph01184
# Removing glyph: glyph01185
# Removing glyph: glyph01186
# Removing glyph: glyph01187
# Removing glyph: glyph01188
# Removing glyph: glyph01189
# Removing glyph: glyph01190
# Removing glyph: glyph01191
# Removing glyph: glyph01192
# Removing glyph: glyph01193
# Removing glyph: glyph01194
# Removing glyph: glyph01195
# Removing glyph: glyph01196
# Removing glyph: glyph01197
# Removing glyph: glyph01198
# Removing glyph: glyph01199
# Removing glyph: glyph01200
# Removing glyph: glyph01201
# Removing glyph: glyph01202
# Removing glyph: glyph01203
# Removing glyph: glyph01204
# Removing glyph: glyph01205
# Removing glyph: glyph01206
# Removing glyph: glyph01207
# Removing glyph: glyph01208
# Removing glyph: glyph01209
# Removing glyph: glyph01210
# Removing glyph: glyph01211
# Removing glyph: glyph01212
# Removing glyph: glyph01213
# Removing glyph: glyph01214
# Removing glyph: glyph01215
# Removing glyph: glyph01216
# Removing glyph: glyph01217
# Removing glyph: glyph01218
# Removing glyph: glyph01219
# Removing glyph: glyph01220
# Removing glyph: glyph01231
# Removing glyph: glyph01232
# Removing glyph: glyph01233
# Removing glyph: glyph01234
# Removing glyph: glyph01235
# Removing glyph: glyph01236
# Removing glyph: glyph01237
# Removing glyph: glyph01252
# Removing glyph: glyph01253
# Removing glyph: glyph01254
# Removing glyph: glyph01255
# Removing glyph: glyph01256
# Removing glyph: glyph01257
# Removing glyph: glyph01260
# Removing glyph: glyph01261
# Removing glyph: glyph01262
# Removing glyph: glyph01263
# Removing glyph: glyph01264
# Removing glyph: glyph01265
# Removing glyph: glyph01266
# Removing glyph: glyph01267
# Removing glyph: glyph01268
# Removing glyph: glyph01281
# Removing glyph: glyph01282
# Removing glyph: glyph01283
# Removing glyph: glyph01284
# Removing glyph: glyph01319
# Removing glyph: glyph01328
# Removing glyph: glyph01329
# Removing glyph: glyph01330
# Removing glyph: glyph01331
# Removing glyph: glyph01332
# Removing glyph: glyph01333
# Removing glyph: glyph01334
# Removing glyph: glyph01355
# Removing glyph: glyph01384
# Removing glyph: glyph01385
# Removing glyph: glyph01386
# Removing glyph: glyph01387
# Removing glyph: glyph01388
# Removing glyph: glyph01389
# Removing glyph: glyph01390
# Removing glyph: glyph01391
# Removing glyph: glyph01392
# Removing glyph: glyph01393
# Removing glyph: glyph01394
# Removing glyph: glyph01395
# Removing glyph: glyph01396
# Removing glyph: glyph01397
# Removing glyph: glyph01398
# Removing glyph: glyph01399
# Removing glyph: glyph01400
# Removing glyph: glyph01401
# Removing glyph: glyph01402
# Removing glyph: glyph01403
# Removing glyph: glyph01404
# Removing glyph: glyph01405
# Removing glyph: glyph01406
# Removing glyph: glyph01407
# Removing glyph: glyph01408
# Removing glyph: glyph01409
# Removing glyph: glyph01410
# Removing glyph: glyph01411
# Removing glyph: glyph01412
# Removing glyph: glyph01413
# Removing glyph: glyph01414
# Removing glyph: glyph01415
# Removing glyph: glyph01416
# Removing glyph: glyph01417
# Removing glyph: glyph01418
# Removing glyph: glyph01435
# Removing glyph: glyph01436
# Removing glyph: glyph01437
# Removing glyph: glyph01438
# Removing glyph: glyph01439
# Removing glyph: glyph01440
# Removing glyph: glyph01441
# Removing glyph: glyph01442
# Removing glyph: glyph01443
# Removing glyph: glyph01444
# Removing glyph: glyph01445
# Removing glyph: glyph01446
# Removing glyph: glyph01447
# Removing glyph: glyph01448
# Removing glyph: glyph01449
# Removing glyph: glyph01450
# Removing glyph: glyph01451
# Removing glyph: glyph01452
# Removing glyph: glyph01453
# Removing glyph: glyph01454
# Removing glyph: glyph01455
# Removing glyph: glyph01456
# Removing glyph: glyph01457
# Removing glyph: glyph01458
# Removing glyph: glyph01459
# Removing glyph: glyph01460
# Removing glyph: glyph01461
# Removing glyph: glyph01462
# Removing glyph: glyph01463
# Removing glyph: glyph01464
# Removing glyph: glyph01465
# Removing glyph: glyph01466
# Removing glyph: glyph01467
# Removing glyph: glyph01468
# Removing glyph: glyph01469
# Removing glyph: glyph01470
# Removing glyph: glyph01471
# Removing glyph: glyph01472
# Removing glyph: glyph01473
# Removing glyph: glyph01474
# Removing glyph: glyph01475
# Removing glyph: glyph01476
# Removing glyph: glyph01477
# Removing glyph: glyph01478
# Removing glyph: glyph01479
# Removing glyph: glyph01480
# Removing glyph: glyph01481
# Removing glyph: glyph01482
# Removing glyph: glyph01483
# Removing glyph: glyph01484
# Removing glyph: glyph01485
# Removing glyph: glyph01486
# Removing glyph: glyph01487
# Removing glyph: glyph01488
# Removing glyph: glyph01489
# Removing glyph: glyph01490
# Removing glyph: glyph01491
# Removing glyph: glyph01492
# Removing glyph: glyph01493
# Removing glyph: glyph01494
# Removing glyph: glyph01495
# Removing glyph: glyph01496
# Removing glyph: glyph01497
# Removing glyph: glyph01498
# Removing glyph: glyph01499
# Removing glyph: glyph01500
# Removing glyph: glyph01501
# Removing glyph: glyph01502
# Removing glyph: glyph01503
# Removing glyph: glyph01504
# Removing glyph: glyph01505
# Removing glyph: glyph01506
# Removing glyph: glyph01507
# Removing glyph: glyph01508
# Removing glyph: glyph01509
# Removing glyph: glyph01510
# Removing glyph: glyph01511
# Removing glyph: glyph01512
# Removing glyph: glyph01513
# Removing glyph: glyph01524
# Removing glyph: glyph01525
# Removing glyph: glyph01638
# Removing glyph: glyph01639
# Removing glyph: glyph01640
# Removing glyph: glyph01641
# Removing glyph: glyph01642
# Removing glyph: glyph01643
# Removing glyph: glyph01644
# Removing glyph: glyph01646
# Removing glyph: glyph01647
# Removing glyph: glyph01648
# Removing glyph: glyph01649
# Removing glyph: glyph01650
# Removing glyph: glyph01651
# Removing glyph: glyph01652
# Removing glyph: glyph01653
# Removing glyph: glyph01654
# Removing glyph: glyph01926
# Removing glyph: glyph01941
# Removing glyph: glyph01943
# Removing glyph: glyph01978
# Removing glyph: glyph01979
# Removing glyph: glyph01980
# Removing glyph: glyph01981
# Removing glyph: glyph01982
# Removing glyph: glyph01983
# Removing glyph: glyph01984
# Removing glyph: glyph01985
# Removing glyph: glyph01986
# Removing glyph: glyph01987
# Removing glyph: glyph01988
# Removing glyph: glyph01989
# Removing glyph: glyph01990
# Removing glyph: glyph01991
# Removing glyph: glyph01992
# Removing glyph: glyph01993
# Removing glyph: glyph02026
# Removing glyph: glyph02027
# Removing glyph: glyph02028
# Removing glyph: glyph02029
# Removed 443 glyphs
# Remaining glyphs: 1587
# Saving font: tmp/base.z03.02.ttf
# Done!
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/base.z03.02.ttf
# Successfully wrote 1586 codepoints to tmp/base.z03.02.ttf.codepoint.csv
# Successfully wrote 1587 glyphs to tmp/base.z03.02.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/base.z03.02.ttf.glyphref.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/base.z03.00.ttf.codepoint.csv glyph_index,glyph_name tmp/base.z03.03.ttf.codepoint.expected.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/base.z03.02.ttf.codepoint.csv glyph_index,glyph_name tmp/base.z03.03.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/diff.py tmp/base.z03.03.ttf.codepoint.expected.csv tmp/base.z03.03.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/glyphcsv_used_mark_rm.py tmp/patch0.z03.00.ttf.glyph.csv tmp/patch0.z03.00.ttf.glyphref.csv tmp/patch0.z03.01.rm_glyph.csv
# Successfully processed 964 glyphs
# Glyphs marked for removal: 81
# Glyphs reachable from cmap: 882
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_rm_glyph.py tmp/patch0.z03.00.ttf tmp/patch0.z03.01.rm_glyph.csv tmp/patch0.z03.02.ttf
# Reading CSV: tmp/patch0.z03.01.rm_glyph.csv
# Found 81 glyphs marked for removal
# Loading font: tmp/patch0.z03.00.ttf
# Removing glyph: glyph00231
# Removing glyph: glyph00321
# Removing glyph: glyph00468
# Removing glyph: glyph00469
# Removing glyph: glyph00484
# Removing glyph: glyph00485
# Removing glyph: glyph00496
# Removing glyph: glyph00497
# Removing glyph: glyph00498
# Removing glyph: glyph00499
# Removing glyph: glyph00500
# Removing glyph: glyph00501
# Removing glyph: glyph00502
# Removing glyph: glyph00503
# Removing glyph: glyph00504
# Removing glyph: glyph00505
# Removing glyph: glyph00506
# Removing glyph: glyph00507
# Removing glyph: glyph00508
# Removing glyph: glyph00509
# Removing glyph: glyph00510
# Removing glyph: glyph00511
# Removing glyph: glyph00512
# Removing glyph: glyph00513
# Removing glyph: glyph00514
# Removing glyph: glyph00515
# Removing glyph: glyph00530
# Removing glyph: glyph00531
# Removing glyph: glyph00532
# Removing glyph: glyph00533
# Removing glyph: glyph00534
# Removing glyph: glyph00535
# Removing glyph: glyph00536
# Removing glyph: glyph00537
# Removing glyph: glyph00554
# Removing glyph: glyph00555
# Removing glyph: glyph00582
# Removing glyph: glyph00583
# Removing glyph: glyph00584
# Removing glyph: glyph00585
# Removing glyph: glyph00649
# Removing glyph: glyph00650
# Removing glyph: glyph00874
# Removing glyph: glyph00875
# Removing glyph: glyph00876
# Removing glyph: glyph00877
# Removing glyph: glyph00878
# Removing glyph: glyph00896
# Removing glyph: glyph00930
# Removing glyph: glyph00931
# Removing glyph: glyph00932
# Removing glyph: glyph00933
# Removing glyph: glyph00934
# Removing glyph: glyph00935
# Removing glyph: glyph00936
# Removing glyph: glyph00937
# Removing glyph: glyph00938
# Removing glyph: glyph00939
# Removing glyph: glyph00940
# Removing glyph: glyph00941
# Removing glyph: glyph00942
# Removing glyph: glyph00943
# Removing glyph: glyph00944
# Removing glyph: glyph00945
# Removing glyph: glyph00946
# Removing glyph: glyph00947
# Removing glyph: glyph00948
# Removing glyph: glyph00949
# Removing glyph: glyph00950
# Removing glyph: glyph00951
# Removing glyph: glyph00952
# Removing glyph: glyph00953
# Removing glyph: glyph00954
# Removing glyph: glyph00955
# Removing glyph: glyph00956
# Removing glyph: glyph00957
# Removing glyph: glyph00958
# Removing glyph: glyph00959
# Removing glyph: glyph00960
# Removing glyph: glyph00961
# Removing glyph: glyph00962
# Removed 81 glyphs
# Remaining glyphs: 883
# Saving font: tmp/patch0.z03.02.ttf
# Done!
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/patch0.z03.02.ttf
# Successfully wrote 882 codepoints to tmp/patch0.z03.02.ttf.codepoint.csv
# Successfully wrote 883 glyphs to tmp/patch0.z03.02.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/patch0.z03.02.ttf.glyphref.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/patch0.z03.00.ttf.codepoint.csv glyph_index,glyph_name tmp/patch0.z03.03.ttf.codepoint.expected.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/patch0.z03.02.ttf.codepoint.csv glyph_index,glyph_name tmp/patch0.z03.03.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/diff.py tmp/patch0.z03.03.ttf.codepoint.expected.csv tmp/patch0.z03.03.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/glyphcsv_used_mark_rm.py tmp/cjk.z03.00.ttf.glyph.csv tmp/cjk.z03.00.ttf.glyphref.csv tmp/cjk.z03.01.rm_glyph.csv
# Successfully processed 65535 glyphs
# Glyphs marked for removal: 21202
# Glyphs reachable from cmap: 44332
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_rm_glyph.py tmp/cjk.z03.00.ttf tmp/cjk.z03.01.rm_glyph.csv tmp/cjk.z03.02.ttf
# Reading CSV: tmp/cjk.z03.01.rm_glyph.csv
# Found 21202 glyphs marked for removal
# Loading font: tmp/cjk.z03.00.ttf
# Removing glyph: glyph00001
# Removing glyph: glyph00002
# Removing glyph: glyph00003
# Removing glyph: glyph00004
# Removing glyph: glyph00005
# Removing glyph: glyph00006
# Removing glyph: glyph00007
# Removing glyph: glyph00008
# Removing glyph: glyph00009
# Removing glyph: glyph00010
# Removing glyph: glyph00011
# Removing glyph: glyph00012
# Removing glyph: glyph00013
# Removing glyph: glyph00014
# Removing glyph: glyph00015
# Removing glyph: glyph00016
# Removing glyph: glyph00017
# Removing glyph: glyph00018
# Removing glyph: glyph00019
# Removing glyph: glyph00020
# Removing glyph: glyph00021
# Removing glyph: glyph00022
# Removing glyph: glyph00023
# Removing glyph: glyph00024
# Removing glyph: glyph00025
# Removing glyph: glyph00026
# Removing glyph: glyph00027
# Removing glyph: glyph00028
# Removing glyph: glyph00029
# Removing glyph: glyph00030
# Removing glyph: glyph00031
# Removing glyph: glyph00032
# Removing glyph: glyph00033
# Removing glyph: glyph00034
# Removing glyph: glyph00035
# Removing glyph: glyph00036
# Removing glyph: glyph00037
# Removing glyph: glyph00038
# Removing glyph: glyph00039
# Removing glyph: glyph00040
# Removing glyph: glyph00041
# Removing glyph: glyph00042
# Removing glyph: glyph00043
# Removing glyph: glyph00044
# Removing glyph: glyph00045
# Removing glyph: glyph00046
# Removing glyph: glyph00047
# Removing glyph: glyph00048
# Removing glyph: glyph00049
# Removing glyph: glyph00050
# Removing glyph: glyph00051
# Removing glyph: glyph00052
# Removing glyph: glyph00053
# Removing glyph: glyph00054
# Removing glyph: glyph00055
# Removing glyph: glyph00056
# Removing glyph: glyph00057
# Removing glyph: glyph00058
# Removing glyph: glyph00059
# Removing glyph: glyph00060
# Removing glyph: glyph00061
# Removing glyph: glyph00062
# Removing glyph: glyph00063
# Removing glyph: glyph00064
# Removing glyph: glyph00065
# Removing glyph: glyph00066
# Removing glyph: glyph00067
# Removing glyph: glyph00068
# Removing glyph: glyph00069
# Removing glyph: glyph00070
# Removing glyph: glyph00071
# Removing glyph: glyph00072
# Removing glyph: glyph00073
# Removing glyph: glyph00074
# Removing glyph: glyph00075
# Removing glyph: glyph00076
# Removing glyph: glyph00077
# Removing glyph: glyph00078
# Removing glyph: glyph00079
# Removing glyph: glyph00080
# Removing glyph: glyph00081
# Removing glyph: glyph00082
# Removing glyph: glyph00083
# Removing glyph: glyph00084
# Removing glyph: glyph00085
# Removing glyph: glyph00086
# Removing glyph: glyph00087
# Removing glyph: glyph00088
# Removing glyph: glyph00089
# Removing glyph: glyph00090
# Removing glyph: glyph00091
# Removing glyph: glyph00092
# Removing glyph: glyph00093
# Removing glyph: glyph00094
# Removing glyph: glyph00095
# Removing glyph: glyph00100
# Removing glyph: glyph00117
# Removing glyph: glyph00726
# Removing glyph: glyph00728
# Removing glyph: glyph00729
# Removing glyph: glyph00733
# Removing glyph: glyph00749
# Removing glyph: glyph00858
# Removing glyph: glyph00917
# Removing glyph: glyph01261
# Removing glyph: glyph01365
# Removing glyph: glyph01383
# Removing glyph: glyph01397
# Removing glyph: glyph01398
# Removing glyph: glyph01683
# Removing glyph: glyph01915
# Removing glyph: glyph01918
# Removing glyph: glyph01920
# Removing glyph: glyph01922
# Removing glyph: glyph01923
# Removing glyph: glyph01928
# Removing glyph: glyph01932
# Removing glyph: glyph01937
# Removing glyph: glyph01939
# Removing glyph: glyph01942
# Removing glyph: glyph01945
# Removing glyph: glyph01952
# Removing glyph: glyph01953
# Removing glyph: glyph01955
# Removing glyph: glyph01958
# Removing glyph: glyph01962
# Removing glyph: glyph01965
# Removing glyph: glyph01967
# Removing glyph: glyph01969
# Removing glyph: glyph01970
# Removing glyph: glyph02031
# Removing glyph: glyph02034
# Removing glyph: glyph02036
# Removing glyph: glyph02038
# Removing glyph: glyph02039
# Removing glyph: glyph02044
# Removing glyph: glyph02048
# Removing glyph: glyph02053
# Removing glyph: glyph02055
# Removing glyph: glyph02059
# Removing glyph: glyph02061
# Removing glyph: glyph02066
# Removing glyph: glyph02067
# Removing glyph: glyph02069
# Removing glyph: glyph02070
# Removing glyph: glyph02072
# Removing glyph: glyph02074
# Removing glyph: glyph02075
# Removing glyph: glyph02080
# Removing glyph: glyph02081
# Removing glyph: glyph02089
# Removing glyph: glyph02090
# Removing glyph: glyph02092
# Removing glyph: glyph02094
# Removing glyph: glyph02097
# Removing glyph: glyph02098
# Removing glyph: glyph02100
# Removing glyph: glyph02103
# Removing glyph: glyph02104
# Removing glyph: glyph02311
# Removing glyph: glyph02443
# Removing glyph: glyph02448
# Removing glyph: glyph02487
# Removing glyph: glyph02490
# Removing glyph: glyph02519
# Removing glyph: glyph02546
# Removing glyph: glyph02550
# Removing glyph: glyph02554
# Removing glyph: glyph02575
# Removing glyph: glyph02587
# Removing glyph: glyph02598
# Removing glyph: glyph02602
# Removing glyph: glyph02628
# Removing glyph: glyph02643
# Removing glyph: glyph02648
# Removing glyph: glyph02672
# Removing glyph: glyph02701
# Removing glyph: glyph02721
# Removing glyph: glyph02805
# Removing glyph: glyph02816
# Removing glyph: glyph02830
# Removing glyph: glyph02841
# Removing glyph: glyph02871
# Removing glyph: glyph02873
# Removing glyph: glyph02883
# Removing glyph: glyph02892
# Removing glyph: glyph02897
# Removing glyph: glyph02916
# Removing glyph: glyph02923
# Removing glyph: glyph02946
# Removing glyph: glyph02971
# Removing glyph: glyph02973
# Removing glyph: glyph02981
# Removing glyph: glyph02985
# Removing glyph: glyph02993
# Removing glyph: glyph02998
# Removing glyph: glyph03010
# Removing glyph: glyph03017
# Removing glyph: glyph03029
# Removing glyph: glyph03064
# Removing glyph: glyph03066
# Removing glyph: glyph03069
# Removing glyph: glyph03074
# Removing glyph: glyph03142
# Removing glyph: glyph03152
# Removing glyph: glyph03164
# Removing glyph: glyph03170
# Removing glyph: glyph03173
# Removing glyph: glyph03178
# Removing glyph: glyph03180
# Removing glyph: glyph03185
# Removing glyph: glyph03190
# Removing glyph: glyph03194
# Removing glyph: glyph03200
# Removing glyph: glyph03203
# Removing glyph: glyph03205
# Removing glyph: glyph03207
# Removing glyph: glyph03210
# Removing glyph: glyph03212
# Removing glyph: glyph03220
# Removing glyph: glyph03225
# Removing glyph: glyph03227
# Removing glyph: glyph03230
# Removing glyph: glyph03238
# Removing glyph: glyph03243
# Removing glyph: glyph03245
# Removing glyph: glyph03249
# Removing glyph: glyph03251
# Removing glyph: glyph03267
# Removing glyph: glyph03280
# Removing glyph: glyph03283
# Removing glyph: glyph03289
# Removing glyph: glyph03292
# Removing glyph: glyph03296
# Removing glyph: glyph03312
# Removing glyph: glyph03319
# Removing glyph: glyph03321
# Removing glyph: glyph03324
# Removing glyph: glyph03332
# Removing glyph: glyph03334
# Removing glyph: glyph03338
# Removing glyph: glyph03341
# Removing glyph: glyph03343
# Removing glyph: glyph03351
# Removing glyph: glyph03391
# Removing glyph: glyph03393
# Removing glyph: glyph03394
# Removing glyph: glyph03404
# Removing glyph: glyph03407
# Removing glyph: glyph03484
# Removing glyph: glyph03490
# Removing glyph: glyph03494
# Removing glyph: glyph03534
# Removing glyph: glyph03545
# Removing glyph: glyph03549
# Removing glyph: glyph03553
# Removing glyph: glyph03559
# Removing glyph: glyph03563
# Removing glyph: glyph03579
# Removing glyph: glyph03589
# Removing glyph: glyph03591
# Removing glyph: glyph03599
# Removing glyph: glyph03632
# Removing glyph: glyph03661
# Removing glyph: glyph03687
# Removing glyph: glyph03732
# Removing glyph: glyph03745
# Removing glyph: glyph03823
# Removing glyph: glyph03853
# Removing glyph: glyph03879
# Removing glyph: glyph03933
# Removing glyph: glyph03945
# Removing glyph: glyph03962
# Removing glyph: glyph03973
# Removing glyph: glyph03989
# Removing glyph: glyph03992
# Removing glyph: glyph04002
# Removing glyph: glyph04003
# Removing glyph: glyph04030
# Removing glyph: glyph04076
# Removing glyph: glyph04092
# Removing glyph: glyph04099
# Removing glyph: glyph04123
# Removing glyph: glyph04175
# Removing glyph: glyph04183
# Removing glyph: glyph04194
# Removing glyph: glyph04196
# Removing glyph: glyph04205
# Removing glyph: glyph04207
# Removing glyph: glyph04215
# Removing glyph: glyph04221
# Removing glyph: glyph04303
# Removing glyph: glyph04311
# Removing glyph: glyph04324
# Removing glyph: glyph04343
# Removing glyph: glyph04353
# Removing glyph: glyph04356
# Removing glyph: glyph04359
# Removing glyph: glyph04383
# Removing glyph: glyph04395
# Removing glyph: glyph04398
# Removing glyph: glyph04400
# Removing glyph: glyph04416
# Removing glyph: glyph04430
# Removing glyph: glyph04481
# Removing glyph: glyph04497
# Removing glyph: glyph04509
# Removing glyph: glyph04516
# Removing glyph: glyph04525
# Removing glyph: glyph04538
# Removing glyph: glyph04541
# Removing glyph: glyph04560
# Removing glyph: glyph04573
# Removing glyph: glyph04575
# Removing glyph: glyph04577
# Removing glyph: glyph04587
# Removing glyph: glyph04623
# Removing glyph: glyph04626
# Removing glyph: glyph04627
# Removing glyph: glyph04629
# Removing glyph: glyph04657
# Removing glyph: glyph04681
# Removing glyph: glyph04728
# Removing glyph: glyph04731
# Removing glyph: glyph04785
# Removing glyph: glyph04857
# Removing glyph: glyph04921
# Removing glyph: glyph04923
# Removing glyph: glyph04935
# Removing glyph: glyph04951
# Removing glyph: glyph04956
# Removing glyph: glyph04958
# Removing glyph: glyph04979
# Removing glyph: glyph04986
# Removing glyph: glyph04989
# Removing glyph: glyph05006
# Removing glyph: glyph05008
# Removing glyph: glyph05012
# Removing glyph: glyph05015
# Removing glyph: glyph05021
# Removing glyph: glyph05023
# Removing glyph: glyph05035
# Removing glyph: glyph05055
# Removing glyph: glyph05063
# Removing glyph: glyph05086
# Removing glyph: glyph05095
# Removing glyph: glyph05103
# Removing glyph: glyph05115
# Removing glyph: glyph05123
# Removing glyph: glyph05125
# Removing glyph: glyph05128
# Removing glyph: glyph05132
# Removing glyph: glyph05133
# Removing glyph: glyph05135
# Removing glyph: glyph05142
# Removing glyph: glyph05163
# Removing glyph: glyph05165
# Removing glyph: glyph05169
# Removing glyph: glyph05178
# Removing glyph: glyph05180
# Removing glyph: glyph05184
# Removing glyph: glyph05190
# Removing glyph: glyph05192
# Removing glyph: glyph05201
# Removing glyph: glyph05203
# Removing glyph: glyph05214
# Removing glyph: glyph05262
# Removing glyph: glyph05264
# Removing glyph: glyph05268
# Removing glyph: glyph05298
# Removing glyph: glyph05351
# Removing glyph: glyph05383
# Removing glyph: glyph05404
# Removing glyph: glyph05414
# Removing glyph: glyph05416
# Removing glyph: glyph05422
# Removing glyph: glyph05424
# Removing glyph: glyph05436
# Removing glyph: glyph05442
# Removing glyph: glyph05447
# Removing glyph: glyph05449
# Removing glyph: glyph05454
# Removing glyph: glyph05458
# Removing glyph: glyph05460
# Removing glyph: glyph05467
# Removing glyph: glyph05474
# Removing glyph: glyph05481
# Removing glyph: glyph05590
# Removing glyph: glyph05594
# Removing glyph: glyph05597
# Removing glyph: glyph05653
# Removing glyph: glyph05657
# Removing glyph: glyph05673
# Removing glyph: glyph05683
# Removing glyph: glyph05689
# Removing glyph: glyph05699
# Removing glyph: glyph05700
# Removing glyph: glyph05706
# Removing glyph: glyph05707
# Removing glyph: glyph05725
# Removing glyph: glyph05738
# Removing glyph: glyph05740
# Removing glyph: glyph05776
# Removing glyph: glyph05831
# Removing glyph: glyph05838
# Removing glyph: glyph05846
# Removing glyph: glyph05852
# Removing glyph: glyph05863
# Removing glyph: glyph05921
# Removing glyph: glyph05945
# Removing glyph: glyph05955
# Removing glyph: glyph06006
# Removing glyph: glyph06016
# Removing glyph: glyph06017
# Removing glyph: glyph06020
# Removing glyph: glyph06035
# Removing glyph: glyph06067
# Removing glyph: glyph06090
# Removing glyph: glyph06129
# Removing glyph: glyph06144
# Removing glyph: glyph06148
# Removing glyph: glyph06200
# Removing glyph: glyph06203
# Removing glyph: glyph06216
# Removing glyph: glyph06244
# Removing glyph: glyph06263
# Removing glyph: glyph06266
# Removing glyph: glyph06277
# Removing glyph: glyph06302
# Removing glyph: glyph06321
# Removing glyph: glyph06351
# Removing glyph: glyph06384
# Removing glyph: glyph06389
# Removing glyph: glyph06396
# Removing glyph: glyph06409
# Removing glyph: glyph06432
# Removing glyph: glyph06441
# Removing glyph: glyph06456
# Removing glyph: glyph06493
# Removing glyph: glyph06510
# Removing glyph: glyph06518
# Removing glyph: glyph06549
# Removing glyph: glyph06557
# Removing glyph: glyph06566
# Removing glyph: glyph06600
# Removing glyph: glyph06601
# Removing glyph: glyph06627
# Removing glyph: glyph06711
# Removing glyph: glyph06715
# Removing glyph: glyph06747
# Removing glyph: glyph06755
# Removing glyph: glyph06766
# Removing glyph: glyph06781
# Removing glyph: glyph06788
# Removing glyph: glyph06803
# Removing glyph: glyph06807
# Removing glyph: glyph06808
# Removing glyph: glyph06811
# Removing glyph: glyph06827
# Removing glyph: glyph06829
# Removing glyph: glyph06836
# Removing glyph: glyph06848
# Removing glyph: glyph06854
# Removing glyph: glyph06859
# Removing glyph: glyph06869
# Removing glyph: glyph06870
# Removing glyph: glyph06879
# Removing glyph: glyph06918
# Removing glyph: glyph06928
# Removing glyph: glyph06955
# Removing glyph: glyph06960
# Removing glyph: glyph06961
# Removing glyph: glyph06983
# Removing glyph: glyph07000
# Removing glyph: glyph07002
# Removing glyph: glyph07005
# Removing glyph: glyph07020
# Removing glyph: glyph07024
# Removing glyph: glyph07029
# Removing glyph: glyph07036
# Removing glyph: glyph07038
# Removing glyph: glyph07041
# Removing glyph: glyph07045
# Removing glyph: glyph07048
# Removing glyph: glyph07058
# Removing glyph: glyph07065
# Removing glyph: glyph07075
# Removing glyph: glyph07077
# Removing glyph: glyph07079
# Removing glyph: glyph07082
# Removing glyph: glyph07086
# Removing glyph: glyph07092
# Removing glyph: glyph07094
# Removing glyph: glyph07096
# Removing glyph: glyph07098
# Removing glyph: glyph07106
# Removing glyph: glyph07108
# Removing glyph: glyph07124
# Removing glyph: glyph07126
# Removing glyph: glyph07132
# Removing glyph: glyph07135
# Removing glyph: glyph07147
# Removing glyph: glyph07153
# Removing glyph: glyph07156
# Removing glyph: glyph07165
# Removing glyph: glyph07168
# Removing glyph: glyph07176
# Removing glyph: glyph07182
# Removing glyph: glyph07186
# Removing glyph: glyph07192
# Removing glyph: glyph07195
# Removing glyph: glyph07198
# Removing glyph: glyph07203
# Removing glyph: glyph07204
# Removing glyph: glyph07219
# Removing glyph: glyph07221
# Removing glyph: glyph07225
# Removing glyph: glyph07229
# Removing glyph: glyph07234
# Removing glyph: glyph07240
# Removing glyph: glyph07242
# Removing glyph: glyph07251
# Removing glyph: glyph07255
# Removing glyph: glyph07266
# Removing glyph: glyph07268
# Removing glyph: glyph07272
# Removing glyph: glyph07277
# Removing glyph: glyph07284
# Removing glyph: glyph07295
# Removing glyph: glyph07301
# Removing glyph: glyph07310
# Removing glyph: glyph07312
# Removing glyph: glyph07320
# Removing glyph: glyph07336
# Removing glyph: glyph07348
# Removing glyph: glyph07377
# Removing glyph: glyph07394
# Removing glyph: glyph07423
# Removing glyph: glyph07483
# Removing glyph: glyph07510
# Removing glyph: glyph07520
# Removing glyph: glyph07542
# Removing glyph: glyph07549
# Removing glyph: glyph07584
# Removing glyph: glyph07597
# Removing glyph: glyph07599
# Removing glyph: glyph07672
# Removing glyph: glyph07694
# Removing glyph: glyph07702
# Removing glyph: glyph07708
# Removing glyph: glyph07716
# Removing glyph: glyph07740
# Removing glyph: glyph07766
# Removing glyph: glyph07788
# Removing glyph: glyph07855
# Removing glyph: glyph07934
# Removing glyph: glyph07944
# Removing glyph: glyph07970
# Removing glyph: glyph08002
# Removing glyph: glyph08005
# Removing glyph: glyph08029
# Removing glyph: glyph08045
# Removing glyph: glyph08066
# Removing glyph: glyph08109
# Removing glyph: glyph08128
# Removing glyph: glyph08130
# Removing glyph: glyph08138
# Removing glyph: glyph08166
# Removing glyph: glyph08196
# Removing glyph: glyph08203
# Removing glyph: glyph08211
# Removing glyph: glyph08224
# Removing glyph: glyph08236
# Removing glyph: glyph08264
# Removing glyph: glyph08274
# Removing glyph: glyph08303
# Removing glyph: glyph08337
# Removing glyph: glyph08400
# Removing glyph: glyph08438
# Removing glyph: glyph08476
# Removing glyph: glyph08487
# Removing glyph: glyph08499
# Removing glyph: glyph08514
# Removing glyph: glyph08522
# Removing glyph: glyph08528
# Removing glyph: glyph08541
# Removing glyph: glyph08639
# Removing glyph: glyph08654
# Removing glyph: glyph08661
# Removing glyph: glyph08676
# Removing glyph: glyph08681
# Removing glyph: glyph08749
# Removing glyph: glyph08767
# Removing glyph: glyph08777
# Removing glyph: glyph08785
# Removing glyph: glyph08798
# Removing glyph: glyph08810
# Removing glyph: glyph08812
# Removing glyph: glyph08816
# Removing glyph: glyph08869
# Removing glyph: glyph08871
# Removing glyph: glyph08874
# Removing glyph: glyph08905
# Removing glyph: glyph08912
# Removing glyph: glyph08952
# Removing glyph: glyph08956
# Removing glyph: glyph08968
# Removing glyph: glyph08977
# Removing glyph: glyph08987
# Removing glyph: glyph09000
# Removing glyph: glyph09048
# Removing glyph: glyph09059
# Removing glyph: glyph09083
# Removing glyph: glyph09092
# Removing glyph: glyph09116
# Removing glyph: glyph09139
# Removing glyph: glyph09150
# Removing glyph: glyph09155
# Removing glyph: glyph09158
# Removing glyph: glyph09198
# Removing glyph: glyph09230
# Removing glyph: glyph09260
# Removing glyph: glyph09299
# Removing glyph: glyph09300
# Removing glyph: glyph09346
# Removing glyph: glyph09413
# Removing glyph: glyph09415
# Removing glyph: glyph09434
# Removing glyph: glyph09454
# Removing glyph: glyph09483
# Removing glyph: glyph09486
# Removing glyph: glyph09497
# Removing glyph: glyph09498
# Removing glyph: glyph09500
# Removing glyph: glyph09501
# Removing glyph: glyph09503
# Removing glyph: glyph09504
# Removing glyph: glyph09507
# Removing glyph: glyph09512
# Removing glyph: glyph09513
# Removing glyph: glyph09516
# Removing glyph: glyph09523
# Removing glyph: glyph09525
# Removing glyph: glyph09528
# Removing glyph: glyph09537
# Removing glyph: glyph09539
# Removing glyph: glyph09541
# Removing glyph: glyph09547
# Removing glyph: glyph09549
# Removing glyph: glyph09554
# Removing glyph: glyph09558
# Removing glyph: glyph09564
# Removing glyph: glyph09571
# Removing glyph: glyph09576
# Removing glyph: glyph09578
# Removing glyph: glyph09582
# Removing glyph: glyph09587
# Removing glyph: glyph09595
# Removing glyph: glyph09596
# Removing glyph: glyph09599
# Removing glyph: glyph09604
# Removing glyph: glyph09608
# Removing glyph: glyph09613
# Removing glyph: glyph09619
# Removing glyph: glyph09625
# Removing glyph: glyph09632
# Removing glyph: glyph09635
# Removing glyph: glyph09637
# Removing glyph: glyph09640
# Removing glyph: glyph09648
# Removing glyph: glyph09649
# Removing glyph: glyph09655
# Removing glyph: glyph09656
# Removing glyph: glyph09662
# Removing glyph: glyph09665
# Removing glyph: glyph09672
# Removing glyph: glyph09675
# Removing glyph: glyph09677
# Removing glyph: glyph09681
# Removing glyph: glyph09686
# Removing glyph: glyph09690
# Removing glyph: glyph09692
# Removing glyph: glyph09694
# Removing glyph: glyph09696
# Removing glyph: glyph09697
# Removing glyph: glyph09699
# Removing glyph: glyph09701
# Removing glyph: glyph09702
# Removing glyph: glyph09704
# Removing glyph: glyph09707
# Removing glyph: glyph09709
# Removing glyph: glyph09711
# Removing glyph: glyph09712
# Removing glyph: glyph09715
# Removing glyph: glyph09719
# Removing glyph: glyph09721
# Removing glyph: glyph09723
# Removing glyph: glyph09726
# Removing glyph: glyph09728
# Removing glyph: glyph09730
# Removing glyph: glyph09734
# Removing glyph: glyph09735
# Removing glyph: glyph09736
# Removing glyph: glyph09738
# Removing glyph: glyph09741
# Removing glyph: glyph09745
# Removing glyph: glyph09746
# Removing glyph: glyph09748
# Removing glyph: glyph09751
# Removing glyph: glyph09760
# Removing glyph: glyph09763
# Removing glyph: glyph09766
# Removing glyph: glyph09768
# Removing glyph: glyph09770
# Removing glyph: glyph09771
# Removing glyph: glyph09773
# Removing glyph: glyph09776
# Removing glyph: glyph09778
# Removing glyph: glyph09780
# Removing glyph: glyph09786
# Removing glyph: glyph09789
# Removing glyph: glyph09793
# Removing glyph: glyph09795
# Removing glyph: glyph09799
# Removing glyph: glyph09801
# Removing glyph: glyph09809
# Removing glyph: glyph09812
# Removing glyph: glyph09818
# Removing glyph: glyph09822
# Removing glyph: glyph09824
# Removing glyph: glyph09826
# Removing glyph: glyph09828
# Removing glyph: glyph09829
# Removing glyph: glyph09832
# Removing glyph: glyph09833
# Removing glyph: glyph09838
# Removing glyph: glyph09843
# Removing glyph: glyph09846
# Removing glyph: glyph09848
# Removing glyph: glyph09850
# Removing glyph: glyph09852
# Removing glyph: glyph09854
# Removing glyph: glyph09855
# Removing glyph: glyph09864
# Removing glyph: glyph09867
# Removing glyph: glyph09871
# Removing glyph: glyph09872
# Removing glyph: glyph09877
# Removing glyph: glyph09883
# Removing glyph: glyph09886
# Removing glyph: glyph09887
# Removing glyph: glyph09889
# Removing glyph: glyph09893
# Removing glyph: glyph09899
# Removing glyph: glyph09906
# Removing glyph: glyph09910
# Removing glyph: glyph09912
# Removing glyph: glyph09920
# Removing glyph: glyph09924
# Removing glyph: glyph09925
# Removing glyph: glyph09931
# Removing glyph: glyph09934
# Removing glyph: glyph09937
# Removing glyph: glyph09946
# Removing glyph: glyph09949
# Removing glyph: glyph09954
# Removing glyph: glyph09955
# Removing glyph: glyph09957
# Removing glyph: glyph09958
# Removing glyph: glyph09960
# Removing glyph: glyph09964
# Removing glyph: glyph09970
# Removing glyph: glyph09972
# Removing glyph: glyph09974
# Removing glyph: glyph09975
# Removing glyph: glyph09978
# Removing glyph: glyph09982
# Removing glyph: glyph09983
# Removing glyph: glyph09985
# Removing glyph: glyph09989
# Removing glyph: glyph09991
# Removing glyph: glyph09993
# Removing glyph: glyph09994
# Removing glyph: glyph10004
# Removing glyph: glyph10006
# Removing glyph: glyph10008
# Removing glyph: glyph10012
# Removing glyph: glyph10015
# Removing glyph: glyph10019
# Removing glyph: glyph10023
# Removing glyph: glyph10024
# Removing glyph: glyph10027
# Removing glyph: glyph10029
# Removing glyph: glyph10031
# Removing glyph: glyph10032
# Removing glyph: glyph10034
# Removing glyph: glyph10038
# Removing glyph: glyph10039
# Removing glyph: glyph10042
# Removing glyph: glyph10043
# Removing glyph: glyph10045
# Removing glyph: glyph10050
# Removing glyph: glyph10051
# Removing glyph: glyph10055
# Removing glyph: glyph10056
# Removing glyph: glyph10059
# Removing glyph: glyph10064
# Removing glyph: glyph10065
# Removing glyph: glyph10066
# Removing glyph: glyph10069
# Removing glyph: glyph10072
# Removing glyph: glyph10075
# Removing glyph: glyph10076
# Removing glyph: glyph10081
# Removing glyph: glyph10083
# Removing glyph: glyph10085
# Removing glyph: glyph10086
# Removing glyph: glyph10088
# Removing glyph: glyph10101
# Removing glyph: glyph10102
# Removing glyph: glyph10106
# Removing glyph: glyph10108
# Removing glyph: glyph10109
# Removing glyph: glyph10113
# Removing glyph: glyph10114
# Removing glyph: glyph10117
# Removing glyph: glyph10119
# Removing glyph: glyph10120
# Removing glyph: glyph10124
# Removing glyph: glyph10125
# Removing glyph: glyph10127
# Removing glyph: glyph10129
# Removing glyph: glyph10131
# Removing glyph: glyph10132
# Removing glyph: glyph10137
# Removing glyph: glyph10138
# Removing glyph: glyph10140
# Removing glyph: glyph10141
# Removing glyph: glyph10143
# Removing glyph: glyph10144
# Removing glyph: glyph10149
# Removing glyph: glyph10150
# Removing glyph: glyph10153
# Removing glyph: glyph10154
# Removing glyph: glyph10157
# Removing glyph: glyph10158
# Removing glyph: glyph10159
# Removing glyph: glyph10163
# Removing glyph: glyph10166
# Removing glyph: glyph10168
# Removing glyph: glyph10171
# Removing glyph: glyph10177
# Removing glyph: glyph10179
# Removing glyph: glyph10184
# Removing glyph: glyph10187
# Removing glyph: glyph10188
# Removing glyph: glyph10190
# Removing glyph: glyph10191
# Removing glyph: glyph10192
# Removing glyph: glyph10195
# Removing glyph: glyph10199
# Removing glyph: glyph10202
# Removing glyph: glyph10212
# Removing glyph: glyph10213
# Removing glyph: glyph10217
# Removing glyph: glyph10220
# Removing glyph: glyph10222
# Removing glyph: glyph10226
# Removing glyph: glyph10229
# Removing glyph: glyph10231
# Removing glyph: glyph10233
# Removing glyph: glyph10235
# Removing glyph: glyph10239
# Removing glyph: glyph10240
# Removing glyph: glyph10244
# Removing glyph: glyph10246
# Removing glyph: glyph10248
# Removing glyph: glyph10251
# Removing glyph: glyph10252
# Removing glyph: glyph10253
# Removing glyph: glyph10256
# Removing glyph: glyph10257
# Removing glyph: glyph10259
# Removing glyph: glyph10262
# Removing glyph: glyph10264
# Removing glyph: glyph10267
# Removing glyph: glyph10268
# Removing glyph: glyph10272
# Removing glyph: glyph10274
# Removing glyph: glyph10276
# Removing glyph: glyph10278
# Removing glyph: glyph10280
# Removing glyph: glyph10282
# Removing glyph: glyph10284
# Removing glyph: glyph10286
# Removing glyph: glyph10287
# Removing glyph: glyph10291
# Removing glyph: glyph10292
# Removing glyph: glyph10293
# Removing glyph: glyph10296
# Removing glyph: glyph10300
# Removing glyph: glyph10303
# Removing glyph: glyph10306
# Removing glyph: glyph10307
# Removing glyph: glyph10309
# Removing glyph: glyph10311
# Removing glyph: glyph10313
# Removing glyph: glyph10315
# Removing glyph: glyph10317
# Removing glyph: glyph10318
# Removing glyph: glyph10323
# Removing glyph: glyph10324
# Removing glyph: glyph10328
# Removing glyph: glyph10329
# Removing glyph: glyph10330
# Removing glyph: glyph10331
# Removing glyph: glyph10333
# Removing glyph: glyph10341
# Removing glyph: glyph10345
# Removing glyph: glyph10346
# Removing glyph: glyph10348
# Removing glyph: glyph10353
# Removing glyph: glyph10355
# Removing glyph: glyph10357
# Removing glyph: glyph10359
# Removing glyph: glyph10360
# Removing glyph: glyph10364
# Removing glyph: glyph10367
# Removing glyph: glyph10368
# Removing glyph: glyph10369
# Removing glyph: glyph10371
# Removing glyph: glyph10372
# Removing glyph: glyph10374
# Removing glyph: glyph10377
# Removing glyph: glyph10380
# Removing glyph: glyph10382
# Removing glyph: glyph10384
# Removing glyph: glyph10385
# Removing glyph: glyph10387
# Removing glyph: glyph10390
# Removing glyph: glyph10393
# Removing glyph: glyph10394
# Removing glyph: glyph10396
# Removing glyph: glyph10398
# Removing glyph: glyph10400
# Removing glyph: glyph10403
# Removing glyph: glyph10405
# Removing glyph: glyph10407
# Removing glyph: glyph10410
# Removing glyph: glyph10412
# Removing glyph: glyph10413
# Removing glyph: glyph10414
# Removing glyph: glyph10416
# Removing glyph: glyph10418
# Removing glyph: glyph10420
# Removing glyph: glyph10422
# Removing glyph: glyph10424
# Removing glyph: glyph10427
# Removing glyph: glyph10430
# Removing glyph: glyph10434
# Removing glyph: glyph10435
# Removing glyph: glyph10440
# Removing glyph: glyph10441
# Removing glyph: glyph10442
# Removing glyph: glyph10445
# Removing glyph: glyph10450
# Removing glyph: glyph10452
# Removing glyph: glyph10454
# Removing glyph: glyph10455
# Removing glyph: glyph10459
# Removing glyph: glyph10465
# Removing glyph: glyph10466
# Removing glyph: glyph10468
# Removing glyph: glyph10469
# Removing glyph: glyph10471
# Removing glyph: glyph10473
# Removing glyph: glyph10476
# Removing glyph: glyph10480
# Removing glyph: glyph10484
# Removing glyph: glyph10487
# Removing glyph: glyph10489
# Removing glyph: glyph10490
# Removing glyph: glyph10492
# Removing glyph: glyph10494
# Removing glyph: glyph10496
# Removing glyph: glyph10497
# Removing glyph: glyph10498
# Removing glyph: glyph10500
# Removing glyph: glyph10501
# Removing glyph: glyph10503
# Removing glyph: glyph10505
# Removing glyph: glyph10507
# Removing glyph: glyph10509
# Removing glyph: glyph10510
# Removing glyph: glyph10513
# Removing glyph: glyph10515
# Removing glyph: glyph10517
# Removing glyph: glyph10518
# Removing glyph: glyph10520
# Removing glyph: glyph10522
# Removing glyph: glyph10523
# Removing glyph: glyph10524
# Removing glyph: glyph10526
# Removing glyph: glyph10527
# Removing glyph: glyph10528
# Removing glyph: glyph10531
# Removing glyph: glyph10532
# Removing glyph: glyph10534
# Removing glyph: glyph10536
# Removing glyph: glyph10538
# Removing glyph: glyph10540
# Removing glyph: glyph10541
# Removing glyph: glyph10545
# Removing glyph: glyph10550
# Removing glyph: glyph10553
# Removing glyph: glyph10555
# Removing glyph: glyph10557
# Removing glyph: glyph10558
# Removing glyph: glyph10560
# Removing glyph: glyph10562
# Removing glyph: glyph10563
# Removing glyph: glyph10566
# Removing glyph: glyph10567
# Removing glyph: glyph10570
# Removing glyph: glyph10571
# Removing glyph: glyph10577
# Removing glyph: glyph10580
# Removing glyph: glyph10581
# Removing glyph: glyph10582
# Removing glyph: glyph10583
# Removing glyph: glyph10584
# Removing glyph: glyph10587
# Removing glyph: glyph10589
# Removing glyph: glyph10591
# Removing glyph: glyph10595
# Removing glyph: glyph10596
# Removing glyph: glyph10597
# Removing glyph: glyph10601
# Removing glyph: glyph10603
# Removing glyph: glyph10605
# Removing glyph: glyph10606
# Removing glyph: glyph10608
# Removing glyph: glyph10610
# Removing glyph: glyph10612
# Removing glyph: glyph10613
# Removing glyph: glyph10617
# Removing glyph: glyph10618
# Removing glyph: glyph10620
# Removing glyph: glyph10621
# Removing glyph: glyph10623
# Removing glyph: glyph10628
# Removing glyph: glyph10629
# Removing glyph: glyph10631
# Removing glyph: glyph10635
# Removing glyph: glyph10638
# Removing glyph: glyph10640
# Removing glyph: glyph10642
# Removing glyph: glyph10644
# Removing glyph: glyph10646
# Removing glyph: glyph10648
# Removing glyph: glyph10649
# Removing glyph: glyph10651
# Removing glyph: glyph10653
# Removing glyph: glyph10655
# Removing glyph: glyph10657
# Removing glyph: glyph10658
# Removing glyph: glyph10662
# Removing glyph: glyph10664
# Removing glyph: glyph10665
# Removing glyph: glyph10668
# Removing glyph: glyph10671
# Removing glyph: glyph10673
# Removing glyph: glyph10675
# Removing glyph: glyph10676
# Removing glyph: glyph10677
# Removing glyph: glyph10679
# Removing glyph: glyph10681
# Removing glyph: glyph10682
# Removing glyph: glyph10683
# Removing glyph: glyph10685
# Removing glyph: glyph10687
# Removing glyph: glyph10689
# Removing glyph: glyph10690
# Removing glyph: glyph10693
# Removing glyph: glyph10696
# Removing glyph: glyph10697
# Removing glyph: glyph10700
# Removing glyph: glyph10701
# Removing glyph: glyph10704
# Removing glyph: glyph10709
# Removing glyph: glyph10710
# Removing glyph: glyph10713
# Removing glyph: glyph10715
# Removing glyph: glyph10716
# Removing glyph: glyph10718
# Removing glyph: glyph10720
# Removing glyph: glyph10723
# Removing glyph: glyph10725
# Removing glyph: glyph10727
# Removing glyph: glyph10728
# Removing glyph: glyph10730
# Removing glyph: glyph10733
# Removing glyph: glyph10734
# Removing glyph: glyph10736
# Removing glyph: glyph10738
# Removing glyph: glyph10739
# Removing glyph: glyph10743
# Removing glyph: glyph10746
# Removing glyph: glyph10748
# Removing glyph: glyph10751
# Removing glyph: glyph10752
# Removing glyph: glyph10755
# Removing glyph: glyph10758
# Removing glyph: glyph10760
# Removing glyph: glyph10761
# Removing glyph: glyph10763
# Removing glyph: glyph10765
# Removing glyph: glyph10770
# Removing glyph: glyph10771
# Removing glyph: glyph10774
# Removing glyph: glyph10776
# Removing glyph: glyph10779
# Removing glyph: glyph10780
# Removing glyph: glyph10782
# ...
# Removing glyph: glyph64933
# Removing glyph: glyph64934
# Removing glyph: glyph64935
# Removing glyph: glyph64936
# Removing glyph: glyph64937
# Removing glyph: glyph64938
# Removing glyph: glyph64939
# Removing glyph: glyph64940
# Removing glyph: glyph64941
# Removing glyph: glyph64942
# Removing glyph: glyph64943
# Removing glyph: glyph64944
# Removing glyph: glyph64945
# Removing glyph: glyph64946
# Removing glyph: glyph64947
# Removing glyph: glyph64948
# Removing glyph: glyph64949
# Removing glyph: glyph64950
# Removing glyph: glyph64951
# Removing glyph: glyph64952
# Removing glyph: glyph64953
# Removing glyph: glyph64954
# Removing glyph: glyph64955
# Removing glyph: glyph64956
# Removing glyph: glyph64957
# Removing glyph: glyph64958
# Removing glyph: glyph64959
# Removing glyph: glyph64960
# Removing glyph: glyph64961
# Removing glyph: glyph64962
# Removing glyph: glyph64963
# Removing glyph: glyph64964
# Removing glyph: glyph64965
# Removing glyph: glyph64966
# Removing glyph: glyph64967
# Removing glyph: glyph64968
# Removing glyph: glyph64969
# Removing glyph: glyph64970
# Removing glyph: glyph64971
# Removing glyph: glyph64972
# Removing glyph: glyph64973
# Removing glyph: glyph64974
# Removing glyph: glyph64975
# Removing glyph: glyph64976
# Removing glyph: glyph64977
# Removing glyph: glyph64978
# Removing glyph: glyph64979
# Removing glyph: glyph64980
# Removing glyph: glyph64981
# Removing glyph: glyph64982
# Removing glyph: glyph64983
# Removing glyph: glyph64984
# Removing glyph: glyph64985
# Removing glyph: glyph64986
# Removing glyph: glyph64987
# Removing glyph: glyph64988
# Removing glyph: glyph64989
# Removing glyph: glyph64990
# Removing glyph: glyph64991
# Removing glyph: glyph64992
# Removing glyph: glyph64993
# Removing glyph: glyph64994
# Removing glyph: glyph64995
# Removing glyph: glyph64996
# Removing glyph: glyph64997
# Removing glyph: glyph64998
# Removing glyph: glyph64999
# Removing glyph: glyph65000
# Removing glyph: glyph65001
# Removing glyph: glyph65002
# Removing glyph: glyph65003
# Removing glyph: glyph65004
# Removing glyph: glyph65005
# Removing glyph: glyph65006
# Removing glyph: glyph65007
# Removing glyph: glyph65008
# Removing glyph: glyph65009
# Removing glyph: glyph65010
# Removing glyph: glyph65011
# Removing glyph: glyph65012
# Removing glyph: glyph65013
# Removing glyph: glyph65014
# Removing glyph: glyph65015
# Removing glyph: glyph65016
# Removing glyph: glyph65017
# Removing glyph: glyph65018
# Removing glyph: glyph65019
# Removing glyph: glyph65020
# Removing glyph: glyph65021
# Removing glyph: glyph65022
# Removing glyph: glyph65023
# Removing glyph: glyph65024
# Removing glyph: glyph65025
# Removing glyph: glyph65026
# Removing glyph: glyph65027
# Removing glyph: glyph65028
# Removing glyph: glyph65029
# Removing glyph: glyph65030
# Removing glyph: glyph65031
# Removing glyph: glyph65032
# Removing glyph: glyph65033
# Removing glyph: glyph65034
# Removing glyph: glyph65035
# Removing glyph: glyph65036
# Removing glyph: glyph65037
# Removing glyph: glyph65038
# Removing glyph: glyph65039
# Removing glyph: glyph65040
# Removing glyph: glyph65041
# Removing glyph: glyph65042
# Removing glyph: glyph65043
# Removing glyph: glyph65044
# Removing glyph: glyph65045
# Removing glyph: glyph65046
# Removing glyph: glyph65047
# Removing glyph: glyph65048
# Removing glyph: glyph65049
# Removing glyph: glyph65050
# Removing glyph: glyph65051
# Removing glyph: glyph65052
# Removing glyph: glyph65053
# Removing glyph: glyph65054
# Removing glyph: glyph65055
# Removing glyph: glyph65056
# Removing glyph: glyph65057
# Removing glyph: glyph65058
# Removing glyph: glyph65059
# Removing glyph: glyph65060
# Removing glyph: glyph65061
# Removing glyph: glyph65062
# Removing glyph: glyph65063
# Removing glyph: glyph65064
# Removing glyph: glyph65065
# Removing glyph: glyph65066
# Removing glyph: glyph65067
# Removing glyph: glyph65068
# Removing glyph: glyph65069
# Removing glyph: glyph65070
# Removing glyph: glyph65071
# Removing glyph: glyph65072
# Removing glyph: glyph65073
# Removing glyph: glyph65074
# Removing glyph: glyph65075
# Removing glyph: glyph65076
# Removing glyph: glyph65077
# Removing glyph: glyph65078
# Removing glyph: glyph65079
# Removing glyph: glyph65080
# Removing glyph: glyph65081
# Removing glyph: glyph65082
# Removing glyph: glyph65083
# Removing glyph: glyph65084
# Removing glyph: glyph65085
# Removing glyph: glyph65086
# Removing glyph: glyph65087
# Removing glyph: glyph65088
# Removing glyph: glyph65089
# Removing glyph: glyph65090
# Removing glyph: glyph65091
# Removing glyph: glyph65092
# Removing glyph: glyph65093
# Removing glyph: glyph65094
# Removing glyph: glyph65095
# Removing glyph: glyph65096
# Removing glyph: glyph65097
# Removing glyph: glyph65098
# Removing glyph: glyph65099
# Removing glyph: glyph65100
# Removing glyph: glyph65101
# Removing glyph: glyph65102
# Removing glyph: glyph65103
# Removing glyph: glyph65104
# Removing glyph: glyph65105
# Removing glyph: glyph65106
# Removing glyph: glyph65107
# Removing glyph: glyph65108
# Removing glyph: glyph65109
# Removing glyph: glyph65110
# Removing glyph: glyph65111
# Removing glyph: glyph65112
# Removing glyph: glyph65113
# Removing glyph: glyph65114
# Removing glyph: glyph65115
# Removing glyph: glyph65116
# Removing glyph: glyph65117
# Removing glyph: glyph65118
# Removing glyph: glyph65119
# Removing glyph: glyph65120
# Removing glyph: glyph65121
# Removing glyph: glyph65122
# Removing glyph: glyph65123
# Removing glyph: glyph65124
# Removing glyph: glyph65125
# Removing glyph: glyph65126
# Removing glyph: glyph65127
# Removing glyph: glyph65128
# Removing glyph: glyph65129
# Removing glyph: glyph65130
# Removing glyph: glyph65131
# Removing glyph: glyph65132
# Removing glyph: glyph65133
# Removing glyph: glyph65134
# Removing glyph: glyph65135
# Removing glyph: glyph65136
# Removing glyph: glyph65137
# Removing glyph: glyph65138
# Removing glyph: glyph65139
# Removing glyph: glyph65140
# Removing glyph: glyph65141
# Removing glyph: glyph65142
# Removing glyph: glyph65143
# Removing glyph: glyph65144
# Removing glyph: glyph65145
# Removing glyph: glyph65146
# Removing glyph: glyph65147
# Removing glyph: glyph65148
# Removing glyph: glyph65149
# Removing glyph: glyph65150
# Removing glyph: glyph65151
# Removing glyph: glyph65152
# Removing glyph: glyph65153
# Removing glyph: glyph65154
# Removing glyph: glyph65155
# Removing glyph: glyph65156
# Removing glyph: glyph65157
# Removing glyph: glyph65158
# Removing glyph: glyph65159
# Removing glyph: glyph65160
# Removing glyph: glyph65161
# Removing glyph: glyph65162
# Removing glyph: glyph65163
# Removing glyph: glyph65164
# Removing glyph: glyph65165
# Removing glyph: glyph65166
# Removing glyph: glyph65167
# Removing glyph: glyph65168
# Removing glyph: glyph65169
# Removing glyph: glyph65170
# Removing glyph: glyph65171
# Removing glyph: glyph65172
# Removing glyph: glyph65173
# Removing glyph: glyph65174
# Removing glyph: glyph65175
# Removing glyph: glyph65176
# Removing glyph: glyph65177
# Removing glyph: glyph65178
# Removing glyph: glyph65179
# Removing glyph: glyph65180
# Removing glyph: glyph65181
# Removing glyph: glyph65182
# Removing glyph: glyph65183
# Removing glyph: glyph65184
# Removing glyph: glyph65185
# Removing glyph: glyph65186
# Removing glyph: glyph65187
# Removing glyph: glyph65188
# Removing glyph: glyph65189
# Removing glyph: glyph65190
# Removing glyph: glyph65191
# Removing glyph: glyph65192
# Removing glyph: glyph65193
# Removing glyph: glyph65194
# Removing glyph: glyph65195
# Removing glyph: glyph65196
# Removing glyph: glyph65197
# Removing glyph: glyph65198
# Removing glyph: glyph65199
# Removing glyph: glyph65200
# Removing glyph: glyph65201
# Removing glyph: glyph65202
# Removing glyph: glyph65203
# Removing glyph: glyph65204
# Removing glyph: glyph65205
# Removing glyph: glyph65206
# Removing glyph: glyph65207
# Removing glyph: glyph65208
# Removing glyph: glyph65209
# Removing glyph: glyph65210
# Removing glyph: glyph65211
# Removing glyph: glyph65212
# Removing glyph: glyph65213
# Removing glyph: glyph65214
# Removing glyph: glyph65215
# Removing glyph: glyph65216
# Removing glyph: glyph65217
# Removing glyph: glyph65218
# Removing glyph: glyph65219
# Removing glyph: glyph65220
# Removing glyph: glyph65221
# Removing glyph: glyph65222
# Removing glyph: glyph65223
# Removing glyph: glyph65224
# Removing glyph: glyph65225
# Removing glyph: glyph65226
# Removing glyph: glyph65227
# Removing glyph: glyph65228
# Removing glyph: glyph65229
# Removing glyph: glyph65230
# Removing glyph: glyph65231
# Removing glyph: glyph65232
# Removing glyph: glyph65233
# Removing glyph: glyph65234
# Removing glyph: glyph65235
# Removing glyph: glyph65236
# Removing glyph: glyph65237
# Removing glyph: glyph65238
# Removing glyph: glyph65239
# Removing glyph: glyph65240
# Removing glyph: glyph65241
# Removing glyph: glyph65242
# Removing glyph: glyph65243
# Removing glyph: glyph65244
# Removing glyph: glyph65245
# Removing glyph: glyph65246
# Removing glyph: glyph65247
# Removing glyph: glyph65248
# Removing glyph: glyph65249
# Removing glyph: glyph65250
# Removing glyph: glyph65251
# Removing glyph: glyph65252
# Removing glyph: glyph65253
# Removing glyph: glyph65254
# Removing glyph: glyph65255
# Removing glyph: glyph65256
# Removing glyph: glyph65257
# Removing glyph: glyph65258
# Removing glyph: glyph65259
# Removing glyph: glyph65260
# Removing glyph: glyph65261
# Removing glyph: glyph65262
# Removing glyph: glyph65263
# Removing glyph: glyph65264
# Removing glyph: glyph65265
# Removing glyph: glyph65266
# Removing glyph: glyph65267
# Removing glyph: glyph65268
# Removing glyph: glyph65269
# Removing glyph: glyph65270
# Removing glyph: glyph65271
# Removing glyph: glyph65272
# Removing glyph: glyph65273
# Removing glyph: glyph65274
# Removing glyph: glyph65275
# Removing glyph: glyph65276
# Removing glyph: glyph65277
# Removing glyph: glyph65278
# Removing glyph: glyph65279
# Removing glyph: glyph65280
# Removing glyph: glyph65281
# Removing glyph: glyph65282
# Removing glyph: glyph65283
# Removing glyph: glyph65284
# Removing glyph: glyph65285
# Removing glyph: glyph65286
# Removing glyph: glyph65287
# Removing glyph: glyph65288
# Removing glyph: glyph65289
# Removing glyph: glyph65290
# Removing glyph: glyph65291
# Removing glyph: glyph65292
# Removing glyph: glyph65293
# Removing glyph: glyph65294
# Removing glyph: glyph65295
# Removing glyph: glyph65296
# Removing glyph: glyph65297
# Removing glyph: glyph65298
# Removing glyph: glyph65299
# Removing glyph: glyph65300
# Removing glyph: glyph65301
# Removing glyph: glyph65302
# Removing glyph: glyph65303
# Removing glyph: glyph65304
# Removing glyph: glyph65305
# Removing glyph: glyph65306
# Removing glyph: glyph65307
# Removing glyph: glyph65308
# Removing glyph: glyph65309
# Removing glyph: glyph65310
# Removing glyph: glyph65311
# Removing glyph: glyph65312
# Removing glyph: glyph65313
# Removing glyph: glyph65314
# Removing glyph: glyph65315
# Removing glyph: glyph65316
# Removing glyph: glyph65317
# Removing glyph: glyph65318
# Removing glyph: glyph65319
# Removing glyph: glyph65320
# Removing glyph: glyph65321
# Removing glyph: glyph65322
# Removing glyph: glyph65323
# Removing glyph: glyph65324
# Removing glyph: glyph65325
# Removing glyph: glyph65326
# Removing glyph: glyph65327
# Removing glyph: glyph65328
# Removing glyph: glyph65329
# Removing glyph: glyph65330
# Removing glyph: glyph65331
# Removing glyph: glyph65332
# Removing glyph: glyph65333
# Removing glyph: glyph65334
# Removing glyph: glyph65335
# Removing glyph: glyph65336
# Removing glyph: glyph65337
# Removing glyph: glyph65338
# Removing glyph: glyph65339
# Removing glyph: glyph65340
# Removing glyph: glyph65341
# Removing glyph: glyph65343
# Removing glyph: glyph65344
# Removing glyph: glyph65345
# Removing glyph: glyph65346
# Removing glyph: glyph65347
# Removing glyph: glyph65348
# Removing glyph: glyph65349
# Removing glyph: glyph65350
# Removing glyph: glyph65351
# Removing glyph: glyph65352
# Removing glyph: glyph65353
# Removing glyph: glyph65354
# Removing glyph: glyph65355
# Removing glyph: glyph65356
# Removing glyph: glyph65357
# Removing glyph: glyph65358
# Removing glyph: glyph65359
# Removing glyph: glyph65360
# Removing glyph: glyph65361
# Removing glyph: glyph65362
# Removing glyph: glyph65363
# Removing glyph: glyph65364
# Removing glyph: glyph65365
# Removing glyph: glyph65366
# Removing glyph: glyph65367
# Removing glyph: glyph65368
# Removing glyph: glyph65369
# Removing glyph: glyph65370
# Removing glyph: glyph65371
# Removing glyph: glyph65372
# Removing glyph: glyph65373
# Removing glyph: glyph65374
# Removing glyph: glyph65375
# Removing glyph: glyph65376
# Removing glyph: glyph65377
# Removing glyph: glyph65378
# Removing glyph: glyph65379
# Removing glyph: glyph65380
# Removing glyph: glyph65381
# Removing glyph: glyph65382
# Removing glyph: glyph65383
# Removing glyph: glyph65384
# Removing glyph: glyph65385
# Removing glyph: glyph65386
# Removing glyph: glyph65387
# Removing glyph: glyph65388
# Removing glyph: glyph65389
# Removing glyph: glyph65390
# Removing glyph: glyph65391
# Removing glyph: glyph65392
# Removing glyph: glyph65393
# Removing glyph: glyph65394
# Removing glyph: glyph65395
# Removing glyph: glyph65396
# Removing glyph: glyph65397
# Removing glyph: glyph65398
# Removing glyph: glyph65399
# Removing glyph: glyph65400
# Removing glyph: glyph65401
# Removing glyph: glyph65402
# Removing glyph: glyph65403
# Removing glyph: glyph65404
# Removing glyph: glyph65405
# Removing glyph: glyph65406
# Removing glyph: glyph65407
# Removing glyph: glyph65408
# Removing glyph: glyph65409
# Removing glyph: glyph65410
# Removing glyph: glyph65411
# Removing glyph: glyph65412
# Removing glyph: glyph65413
# Removing glyph: glyph65414
# Removing glyph: glyph65415
# Removing glyph: glyph65416
# Removing glyph: glyph65417
# Removing glyph: glyph65418
# Removing glyph: glyph65419
# Removing glyph: glyph65420
# Removing glyph: glyph65421
# Removing glyph: glyph65422
# Removing glyph: glyph65423
# Removing glyph: glyph65424
# Removing glyph: glyph65425
# Removing glyph: glyph65426
# Removing glyph: glyph65427
# Removing glyph: glyph65428
# Removing glyph: glyph65429
# Removing glyph: glyph65430
# Removing glyph: glyph65431
# Removing glyph: glyph65432
# Removing glyph: glyph65433
# Removing glyph: glyph65434
# Removing glyph: glyph65435
# Removing glyph: glyph65436
# Removing glyph: glyph65437
# Removing glyph: glyph65438
# Removing glyph: glyph65439
# Removing glyph: glyph65440
# Removing glyph: glyph65441
# Removing glyph: glyph65442
# Removing glyph: glyph65443
# Removing glyph: glyph65444
# Removing glyph: glyph65445
# Removing glyph: glyph65446
# Removing glyph: glyph65447
# Removing glyph: glyph65448
# Removing glyph: glyph65449
# Removing glyph: glyph65450
# Removing glyph: glyph65451
# Removing glyph: glyph65452
# Removing glyph: glyph65453
# Removing glyph: glyph65454
# Removing glyph: glyph65455
# Removing glyph: glyph65456
# Removing glyph: glyph65457
# Removing glyph: glyph65458
# Removing glyph: glyph65459
# Removing glyph: glyph65460
# Removing glyph: glyph65461
# Removing glyph: glyph65462
# Removing glyph: glyph65463
# Removing glyph: glyph65464
# Removing glyph: glyph65465
# Removing glyph: glyph65466
# Removing glyph: glyph65467
# Removing glyph: glyph65468
# Removing glyph: glyph65469
# Removing glyph: glyph65470
# Removing glyph: glyph65471
# Removing glyph: glyph65472
# Removing glyph: glyph65473
# Removing glyph: glyph65474
# Removing glyph: glyph65475
# Removing glyph: glyph65476
# Removing glyph: glyph65477
# Removing glyph: glyph65478
# Removing glyph: glyph65479
# Removing glyph: glyph65480
# Removing glyph: glyph65481
# Removing glyph: glyph65482
# Removing glyph: glyph65483
# Removing glyph: glyph65484
# Removing glyph: glyph65493
# Removing glyph: glyph65509
# Removing glyph: glyph65514
# Removing glyph: glyph65531
# Removing glyph: glyph65532
# Removing glyph: glyph65533
# Removing glyph: glyph65534
# Removed 21202 glyphs
# Remaining glyphs: 44333
# Saving font: tmp/cjk.z03.02.ttf
# Done!
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/cjk.z03.02.ttf
# Successfully wrote 44810 codepoints to tmp/cjk.z03.02.ttf.codepoint.csv
# Successfully wrote 44333 glyphs to tmp/cjk.z03.02.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/cjk.z03.02.ttf.glyphref.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/cjk.z03.00.ttf.codepoint.csv glyph_index,glyph_name tmp/cjk.z03.03.ttf.codepoint.expected.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_rm_column.py tmp/cjk.z03.02.ttf.codepoint.csv glyph_index,glyph_name tmp/cjk.z03.03.ttf.codepoint.actual.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/diff.py tmp/cjk.z03.03.ttf.codepoint.expected.csv tmp/cjk.z03.03.ttf.codepoint.actual.csv

# %%
ttf_milestone(4)
# Out:
# Z04 milestone
# Checking font: tmp/base.z03.99.ttf
# Font validation passed: tmp/base.z03.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/base.z04.00.ttf tmp/base.z04.00.ttf.data.yaml
# Font metadata written to tmp/base.z04.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/base.z04.00.ttf
# Successfully wrote 1586 codepoints to tmp/base.z04.00.ttf.codepoint.csv
# Successfully wrote 1587 glyphs to tmp/base.z04.00.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/base.z04.00.ttf.glyphref.csv
# Checking font: tmp/patch0.z03.99.ttf
# Font validation passed: tmp/patch0.z03.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/patch0.z04.00.ttf tmp/patch0.z04.00.ttf.data.yaml
# Font metadata written to tmp/patch0.z04.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/patch0.z04.00.ttf
# Successfully wrote 882 codepoints to tmp/patch0.z04.00.ttf.codepoint.csv
# Successfully wrote 883 glyphs to tmp/patch0.z04.00.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/patch0.z04.00.ttf.glyphref.csv
# Checking font: tmp/cjk.z03.99.ttf
# Font validation passed: tmp/cjk.z03.99.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/cjk.z04.00.ttf tmp/cjk.z04.00.ttf.data.yaml
# Font metadata written to tmp/cjk.z04.00.ttf.data.yaml
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/cjk.z04.00.ttf
# Successfully wrote 44810 codepoints to tmp/cjk.z04.00.ttf.codepoint.csv
# Successfully wrote 44333 glyphs to tmp/cjk.z04.00.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/cjk.z04.00.ttf.glyphref.csv

# %%
# get base font informations

# Get ASCII chars from base font
print("Getting ASCII characters from base font...")
py(
    "ttf/filter_char_csv.py",
    "tmp/base.z04.00.ttf.codepoint.csv",
    "ascii",
    "tmp/base.z04.01.ascii.csv"
)

# Get big chars from base font
print("Getting big characters from base font...")
py(
    "ttf/filter_char_csv.py",
    "tmp/base.z04.00.ttf.codepoint.csv",
    "upper,number",
    "tmp/base.z04.01.big.csv"
)

base_half_advance_width = py(
    "utils/csv_query.py",
    "tmp/base.z04.00.ttf.codepoint.csv",
    "codepoint_dec", "79", "advance_width",
    stdout=False,
)
base_half_advance_width = int(base_half_advance_width)
print("Base font half advance width:", base_half_advance_width)

base_big_max_height = py(
    "utils/csv_query.py",
    "tmp/base.z04.01.big.csv",
    "yMax", "__MAX__", "yMax",
    stdout=False,
)
base_big_max_height = int(base_big_max_height)
print("Base font big max height:", base_big_max_height)
# Out:
# Getting ASCII characters from base font...
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/filter_char_csv.py tmp/base.z04.00.ttf.codepoint.csv ascii tmp/base.z04.01.ascii.csv
# Filtered 96 characters matching types [ascii] from tmp/base.z04.00.ttf.codepoint.csv to tmp/base.z04.01.ascii.csv
# Getting big characters from base font...
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/filter_char_csv.py tmp/base.z04.00.ttf.codepoint.csv upper,number tmp/base.z04.01.big.csv
# Filtered 36 characters matching types [upper, number] from tmp/base.z04.00.ttf.codepoint.csv to tmp/base.z04.01.big.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_query.py tmp/base.z04.00.ttf.codepoint.csv codepoint_dec 79 advance_width
# Base font half advance width: 1200
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_query.py tmp/base.z04.01.big.csv yMax __MAX__ yMax
# Base font big max height: 1399

# %%
## Scale patch0 font to match base font

# Get big chars from patch0 font
print("Getting big characters from patch0 font...")
py(
    "ttf/filter_char_csv.py",
    "tmp/patch0.z04.00.ttf.codepoint.csv",
    "upper,number",
    "tmp/patch0.z04.01.big.csv"
)

patch0_big_max_height = py(
    "utils/csv_query.py",
    "tmp/patch0.z04.01.big.csv",
    "yMax", "__MAX__", "yMax",
    stdout=False,
)
patch0_big_max_height = int(patch0_big_max_height)
print("Patch0 font big max height:", patch0_big_max_height)

patch0_scale_factor = float(base_big_max_height) / float(patch0_big_max_height)
print("Patch0 font scale factor:", patch0_scale_factor)
# Out:
# Getting big characters from patch0 font...
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/filter_char_csv.py tmp/patch0.z04.00.ttf.codepoint.csv upper,number tmp/patch0.z04.01.big.csv
# Filtered 36 characters matching types [upper, number] from tmp/patch0.z04.00.ttf.codepoint.csv to tmp/patch0.z04.01.big.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/csv_query.py tmp/patch0.z04.01.big.csv yMax __MAX__ yMax
# Patch0 font big max height: 634
# Patch0 font scale factor: 2.2066246056782335

# %%
# Scale patch0 font
print("Scaling patch0 font...")
py(
    "ttf/scale_ttf.py",
    "tmp/patch0.z04.00.ttf",
    "tmp/patch0.z04.00.ttf.glyph.csv",
    str(patch0_scale_factor),
    "tmp/patch0.z04.02.ttf"
)

# Dump scaled patch0 font char CSV
print("Dumping scaled patch0 font char CSV...")
py(
    "ttf/dump_char_csv.py",
    "tmp/patch0.z04.02.ttf"
)

# py(
#     "ttf/dump_data_yaml.py",
#     "tmp/patch0.z04.02.ttf",
#     "tmp/patch0.z04.02.ttf.data.yaml",
# )

pass
# Out:
# Scaling patch0 font...
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/scale_ttf.py tmp/patch0.z04.00.ttf tmp/patch0.z04.00.ttf.glyph.csv 2.2066246056782335 tmp/patch0.z04.02.ttf
# Loading font...
# Parsing glyph CSV...
# Found 882 glyphs to scale
# Scale factor: 2.206625
# Scaling font...
# Scale factor 2.2066246056782335 exceeds F2Dot14 limit, decomposing composite glyphs...
# Saving scaled font to tmp/patch0.z04.02.ttf...
# Done!
# Dumping scaled patch0 font char CSV...
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_char_csv.py tmp/patch0.z04.02.ttf
# Successfully wrote 882 codepoints to tmp/patch0.z04.02.ttf.codepoint.csv
# Successfully wrote 883 glyphs to tmp/patch0.z04.02.ttf.glyph.csv
# Successfully wrote 0 glyph references to tmp/patch0.z04.02.ttf.glyphref.csv
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/patch0.z04.02.ttf tmp/patch0.z04.02.ttf.data.yaml
# Font metadata written to tmp/patch0.z04.02.ttf.data.yaml

# %%
# update units_per_em

## get base font units_per_em
base_units_per_em = py(
    "utils/yq.py",
    "tmp/base.z04.00.ttf.data.yaml",
    "head.unitsPerEm",
    stdout=False,
)
base_units_per_em = int(base_units_per_em)
print("Base font units_per_em:", base_units_per_em)

py(
    "ttf/ttf_set_data.py",
    "tmp/patch0.z04.02.ttf",
    "--units-per-em", str(base_units_per_em),
    "tmp/patch0.z04.03.ttf",
)

py(
    "ttf/dump_data_yaml.py",
    "tmp/patch0.z04.03.ttf",
    "tmp/patch0.z04.03.ttf.data.yaml",
)

pass
# Out:
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/utils/yq.py tmp/base.z04.00.ttf.data.yaml head.unitsPerEm
# Base font units_per_em: 1950
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/ttf_set_data.py tmp/patch0.z04.02.ttf --units-per-em 1950 tmp/patch0.z04.03.ttf
# Updated unitsPerEm to 1950
# Saved font to tmp/patch0.z04.03.ttf
# Running: tmp/venv/bin/python /home/luzi82/project/mono-merge/ttf/dump_data_yaml.py tmp/patch0.z04.03.ttf tmp/patch0.z04.03.ttf.data.yaml
# Font metadata written to tmp/patch0.z04.03.ttf.data.yaml

# %%
# modify advance_width of patch0.scaled.ttf to match base font half advance width
print("Modifying advance_width of patch0.scaled.ttf to match base font half advance width...")
py(
    "ttf/cal_shift_x_csv.py",
    "tmp/patch0.scaled.char.csv",
    str(base_half_advance_width),
    "tmp/patch0.scaled.char.shift_x.csv"
)

py(
    "ttf/modify_advance_width.py",
    "tmp/patch0.scaled.ttf",
    "tmp/patch0.scaled.char.shift_x.csv",
    "tmp/patch0.scaled.aw.ttf"
)

# py(
#     "ttf/dump_char_csv.py",
#     "tmp/patch0.scaled.aw.ttf",
#     "tmp/patch0.scaled.aw.char.csv"
# )

# %%
# Get the advance_width of char O
print("Getting advance width of character 'O'...")
patch0_half_advance_width = py(
    "utils/csv_query.py",
    "tmp/patch0.char.csv",
    "codepoint_dec", "79",
    "advance_width"
)
cjk_half_advance_width = py(
    "utils/csv_query.py",
    "tmp/cjk.char.csv",
    "codepoint_dec", "79",
    "advance_width"
)
print(f"Base half advance width: {base_half_advance_width}")
print(f"Patch0 half advance width: {patch0_half_advance_width}")
print(f"CJK half advance width: {cjk_half_advance_width}")
